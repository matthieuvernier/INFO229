# %% [markdown]
# # TP 0: Introducción al Web Scraping en Python

# %% [markdown]
# ## 1. Realizar consultas HTTP en Python: _Requests_
#
# [_Requests_](https://2.python-requests.org//es/latest/) es una librería Python que facilita el envio de consultas HTTP/1.1.

# %%
import requests

# %%
URL = "https://www.latercera.com/"

r = requests.get(URL)

# %%
print(r.headers)
# Out:
# {'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'X-Amz-Cf-Pop': 'GIG51-C1', 'Access-Control-Allow-Origin': '*', 'Server': 'nginx', 'DELIVERY': 'TKZP-2', 'X-Amz-Cf-Id': 'G9hyBQHov3-DGfv7IoQfBNiLYnq2enLkOf690xbHQv2D8n-boTG0Cw==', 'Date': 'Fri, 30 Aug 2019 20:55:12 GMT', 'Connection': 'keep-alive', 'Via': '1.1 2e92b6c08d7d34d4be9cc42c82d17530.cloudfront.net (CloudFront)', 'Age': '50', 'Cache-Control': 'public, max-age=128, s-maxage=128', 'Link': '<https://www.latercera.com/wp-json/>; rel="https://api.w.org/"', 'X-Cache': 'Hit from cloudfront', 'Vary': 'Accept-Encoding'}

# %%
print(r.headers['Content-Type'])
print(r.encoding)
# Out:
# text/html; charset=UTF-8
# UTF-8

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="es-CL">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# <meta http-equiv="refresh" content="300"><title>La Tercera - Noticias, deportes y actualidad de Chile y del mundo</title>
# <link rel="profile" href="http://gmpg.org/xfn/11">
#
# <!-- This site is optimized with the Yoast SEO plugin v5.1 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta name="description" content="Infórmate primero y con profundidad de todo el acontecer del país y el mundo en política, negocios, deportes, cultura, entretención y tendencias."/>
# <link rel="canonical" href="https://www.latercera.com/" />
# <meta property="og:locale" content="es_ES" />
# <meta property="og:type" content="website" />
# <meta property="og:title" content="La Tercera - Noticias, deportes y actualidad de Chile y del mundo" />
# <meta property="og:description" content="Infórmate primero y con profundidad de todo el acontecer del país y el mundo en política, negocios, deportes, cultura, entretención y tendencias." />
# <meta property="og:url" content="https://www.latercera.com/" />
# <meta property="og:site_name" content="La Tercera" />
# <meta property="fb:app_id" content="1890042961024301" />
# <meta property="og:image" content="http://s2.latercera.com/wp-content/uploads/2018/01/share-fb-la-tercera.png" />
# <meta name="twitter:card" content="summary_large_image" />
# <meta name="twitter:description" content="Infórmate primero y con profundidad de todo el acontecer del país y el mundo en política, negocios, deportes, cultura, entretención y tendencias." />
# <meta name="twitter:title" content="La Tercera - Noticias, deportes y actualidad de Chile y del mundo" />
# <meta name="twitter:site" content="@latercera" />
# <meta name="twitter:image" content="http://s2.latercera.com/wp-content/uploads/2018/01/share-fb-la-tercera.png" />
# <script type='application/ld+json'>{"@context":"http:\/\/schema.org","@type":"WebSite","@id":"#website","url":"https:\/\/www.latercera.com\/","name":"La Tercera","potentialAction":{"@type":"SearchAction","target":"https:\/\/www.latercera.com\/?s={search_term_string}","query-input":"required name=search_term_string"}}</script>
# <script type='application/ld+json'>{"@context":"http:\/\/schema.org","@type":"Organization","url":"https:\/\/www.latercera.com\/","sameAs":["https:\/\/www.facebook.com\/laterceracom","https:\/\/www.instagram.com\/laterceracom\/","https:\/\/www.youtube.com\/user\/latercera","https:\/\/twitter.com\/latercera"],"@id":"#organization","name":"La Tercera","logo":"http:\/\/www.latercera.com\/wp-content\/uploads\/2018\/01\/la-tercera-web.png"}</script>
# <meta name="google-site-verification" content="l5Vp7Fbw54wRvEQHIcCXB0Z3kLl7qY8VDkWV8IV0HxM" />
# <!-- / Yoast SEO plugin. -->
#
# <link rel='dns-prefetch' href='//secure.widget.cloud.opta.net' />
# <link rel='dns-prefetch' href='//fonts.googleapis.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# <link rel='stylesheet' id='gnuble-style-css'  href='https://s1.latercera.com/wp-content/themes/gnuble/style.css?ver=4.8' type='text/css' media='all' />
# <link rel='stylesheet' id='bootstrap-css'  href='https://s1.latercera.com/wp-content/themes/gnuble/css/bootstrap.min.css?ver=4.8' type='text/css' media='all' />
# <link rel='stylesheet' id='owlcarousel-min-css'  href='https://s2.latercera.com/wp-content/themes/gnuble/css/owlcarousel/owl.carousel.min.css?ver=4.8' type='text/css' media='all' />
# <link rel='stylesheet' id='owlcarousel-default-css'  href='https://s2.latercera.com/wp-content/themes/gnuble/css/owlcarousel/owl.theme.default.min.css?ver=4.8' type='text/css' media='all' />
# <link rel='stylesheet' id='fuentes-lt-css'  href='https://s2.latercera.com/wp-content/themes/gnuble/css/fuentes-lt.css?ver=1.3' type='text/css' media='all' />
# <link rel='stylesheet' id='header-css'  href='https://s1.latercera.com/wp-content/themes/gnuble/css/header.css?ver=5.6.3' type='text/css' media='all' />
# <link rel='stylesheet' id='footer-css'  href='https://s1.latercera.com/wp-content/themes/gnuble/css/footer.css?ver=1.2.1.1' type='text/css' media='all' />
# <link rel='stylesheet' id='main-css'  href='https://s2.latercera.com/wp-content/themes/gnuble/css/main.css?ver=7.0.1.3' type='text/css' media='all' />
# <link rel='stylesheet' id='opta-original-css'  href='https://secure.widget.cloud.opta.net/v3/css/v3.football.opta-widgets.css?ver=1.1' type='text/css' media='all' />
# <link rel='stylesheet' id='opta-custom-css'  href='https://s2.latercera.com/wp-content/themes/gnuble/css/opta-lt-custom.css?ver=1.2' type='text/css' media='all' />
# <link rel='stylesheet' id='iefix-css'  href='https://s1.latercera.com/wp-content/themes/gnuble/css/iefix.css?ver=1.0.0' type='text/css' media='screen and (-ms-high-contrast: active), (-ms-high-contrast: none)' />
# <link rel='stylesheet' id='merriweather-css'  href='https://fonts.googleapis.com/css?family=Merriweather%3A300%2C400%2C400i%2C700%2C900%7COpen+Sans%3A300%2C400&#038;ver=4.8' type='text/css' media='all' />
# <link rel='stylesheet' id='customscroll-min-css'  href='https://s2.latercera.com/wp-content/themes/gnuble/css/jquery.mCustomScrollbar.min.css?ver=4.8' type='text/css' media='all' />
# <link rel='stylesheet' id='readmore-css'  href='https://s1.latercera.com/wp-content/themes/gnuble/css/readmore.css?ver=1.1.2' type='text/css' media='all' />
# <script type='text/javascript' src='https://s1.latercera.com/wp-includes/js/jquery/jquery.js?ver=1.12.4'></script>
# <script type='text/javascript' src='https://s2.latercera.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1'></script>
# <link rel='https://api.w.org/' href='https://www.latercera.com/wp-json/' />
#
# <link rel="apple-touch-icon" sizes="180x180" href="https://s2.latercera.com/wp-content/themes/gnuble/favicon/apple-touch-icon.png">
# <link rel="icon" type="image/png" href="https://s1.latercera.com/wp-content/themes/gnuble/favicon/favicon-32x32.png" sizes="32x32">
# <link rel="icon" type="image/png" href="https://s1.latercera.com/wp-content/themes/gnuble/favicon/favicon-16x16.png" sizes="16x16">
# <link rel="manifest" href="https://s2.latercera.com/wp-content/themes/gnuble/favicon/manifest.json">
# <link rel="mask-icon" href="https://s1.latercera.com/wp-content/themes/gnuble/favicon/safari-pinned-tab.svg" color="#aa272f">
# <meta name="theme-color" content="#ffffff">
# 	<meta name="cXenseParse:pageclass" content="frontpage">
# 		<style type="text/css">.recentcomments a{display:inline !important;padding:0 !important;margin:0 !important;}</style>
# 		<meta property="fb:pages" content="204430603582" />
# <script src="https://secure.widget.cloud.opta.net/v3/v3.opta-widgets.js"></script>
# <script>
#     var opta_settings = {
#             subscription_id: '83f090439770a6e6cc0cb324504524e7',
#             language: 'es_CO',
#             timezone: 'user'
#     };
# </script>
# <script type='text/javascript'>
#   (function() {
#     var useSSL = 'https:' == document.location.protocol;
#     var src = (useSSL ? 'https:' : 'http:') +
#         '//www.googletagservices.com/tag/js/gpt.js';
#     document.write('<scr' + 'ipt src="' + src + '"></scr' + 'ipt>');
#   })();
# </script>
#
#
# <!-- DFP -->
# <script src="//www.googletagservices.com/tag/js/gpt.js"></script>
#
# <script async src="https://s2.latercera.com/wp-content/themes/gnuble/js/prebid.js"></script>
#
# <!-- NUEVA Cxense script begin -->
# <script type="text/javascript">
# var cX = window.cX = window.cX || {}; cX.callQueue = cX.callQueue || [];
# cX.CCE = cX.CCE || {}; cX.CCE.callQueue = cX.CCE.callQueue || [];
#
# value = getVariable ("user");
#
# if( value ) {  cX.callQueue.push(["addExternalId", {"id": value, "type":"cps"}]);}
#
#     cX.callQueue.push(['setSiteId', '1145199474754072327']);
#     cX.CCE.callQueue.push(['sendPageViewEvent','cps', '6b5338b4d6371a3b98418bd8e3abebed490bd2d9']);
#
#     (function(d,s,e,t){e=d.createElement(s);e.type='text/java'+s;e.async='async';e.src='https://cdn.cxense.com/cx.cce.js';t=d.getElementsByTagName(s)[0];t.parentNode.insertBefore(e,t);})(document,'script');
#
#     function getVariable(name) {
#         if (name = (new RegExp('[?&]' + encodeURIComponent(name) + '=([^&]*)')).exec(location.search))
#             return decodeURIComponent(name[1]);
#     }
#
#     cX.callQueue.push(['getUserSegmentIds', { persistedQueryId: "1e71f5d217d2466a2c28a8f572d1e7cdb635b306", callback: function(segments) {
#     if(typeof window.localStorage === 'object' && typeof window.localStorage.getItem === 'function') {
#         localStorage.setItem("cxSegments", segments.join(","));
#     }
#     }}]);
#
#     function getUserSegmentIdsLocal() {
#         var segments = [];
#         if(typeof window.localStorage === 'object' && typeof window.localStorage.getItem === 'function' && localStorage.getItem("cxSegments") !== null && localStorage.getItem("cxSegments").length>0) {
#             segments = localStorage.getItem("cxSegments").split(',');
#         }
#         return segments;
#     }
#
# </script>
# <script type="text/javascript">
#     (function(d,s,e,t){e=d.createElement(s);e.type='text/java'+s;e.async='async';
#     e.src='http'+('https:'===location.protocol?'s://s':'://')+'cdn.cxense.com/cx.js';
#     t=d.getElementsByTagName(s)[0];t.parentNode.insertBefore(e,t);})(document,'script');
# </script>
# <!-- Cxense script end NUEVA -->
#
# 	<script type='text/javascript'>
#
#         var billboard = [
#             [728, 90]
#         ];
#         var midbanner = [
#             [220, 90]
#         ];
#         var roba_pagina = [
#             [300, 250]
#         ];
#         var boton_pagina = [
#             [300, 50]
#         ];
#         var fullbanner = [
#             [970, 250],
#             [728, 90],
#             [300, 250]
#         ];
#         var skycrapper = [
#             [160, 600],
#             [120, 600]
#         ];
#         var desktopSizes = [
#             [970, 250],
#             [970, 90],
#             [160, 600],
#             [120, 600],
#             [300, 250]
#         ];
#         var tabletSizes = [
#             [728, 90],
#             [120, 600],
#             [300, 250]
#         ];
#         var phoneSizes = [
#             [320, 100],
#             [320, 50],
#             [300, 250]
#         ];
#         var allSizes = [
#             [970, 250],
#             [728, 90],
#             [320, 100],
#             [320, 50],
#             [300, 600],
#             [300, 250],
#             [160, 600]
#         ];
#         var PREBID_TIMEOUT = 2000;
#
#                 var adUnits = [{
#                 code: '/124506296/La_Tercera_com/LT_home/home_300x250-C',
#                 mediaTypes: {
#                     banner: {
#                         sizes: roba_pagina
#                     }
#                 },
#                 bids: [{
#                     bidder: 'appnexus',
#                     params: {
#                         placementId: 15256528
#                     }
#                 }]
#             }, {
#                 code: '/124506296/La_Tercera_com/LT_home/home_300x250-D',
#                 mediaTypes: {
#                     banner: {
#                         sizes: roba_pagina
#                     }
#                 },
#                 bids: [{
#                     bidder: 'appnexus',
#                     params: {
#                         placementId: 15256530
#                     }
#                 }]
#             }, {
#                 code: '/124506296/La_Tercera_com/LT_home/home_300x250-E',
#                 mediaTypes: {
#                     banner: {
#                         sizes: roba_pagina
#                     }
#                 },
#                 bids: [{
#                     bidder: 'appnexus',
#                     params: {
#                         placementId: 15256531
#                     }
#                 }]
#             }, {
#                 code: '/124506296/La_Tercera_com/LT_home/home_300x250-F',
#                 mediaTypes: {
#                     banner: {
#                         sizes: roba_pagina
#                     }
#                 },
#                 bids: [{
#                     bidder: 'appnexus',
#                     params: {
#                         placementId: 15256533
#                     }
#                 }]
#             }, {
#                 code: '/124506296/La_Tercera_com/LT_home/home_300x250-G',
#                 mediaTypes: {
#                     banner: {
#                         sizes: roba_pagina
#                     }
#                 },
#                 bids: [{
#                     bidder: 'appnexus',
#                     params: {
#                         placementId: 15256534
#                     }
#                 }]
#             },{
#                 code: '/124506296/La_Tercera_com/LT_home/home_300x250-H',
#                 mediaTypes: {
#                     banner: {
#                         sizes: roba_pagina
#                     }
#                 },
#                 bids: [{
#                     bidder: 'appnexus',
#                     params: {
#                         placementId: 15256536
#                     }
#                 }]
#             },{
#                 code: '/124506296/La_Tercera_com/LT_home/home_300x50',
#                 mediaTypes: {
#                     banner: {
#                         sizes: boton_pagina
#                     }
#                 },
#                 bids: [{
#                     bidder: 'appnexus',
#                     params: {
#                         placementId: 15256537
#                     }
#                 }]
#             }, {
#                 code: '/124506296/La_Tercera_com/LT_home/home_160x600',
#                 mediaTypes: {
#                     banner: {
#                         sizes: skycrapper
#                     }
#                 },
#                 bids: [{
#                     bidder: 'appnexus',
#                     params: {
#                         placementId: 15256539
#                     }
#                 }]
#             }, {
#                 code: '/124506296/La_Tercera_com/LT_home/home_970x250-A',
#                 mediaTypes: {
#                     banner: {
#                         sizes: fullbanner
#                     }
#                 },
#                 bids: [{
#                     bidder: 'appnexus',
#                     params: {
#                         placementId: 15256541
#                     }
#                 }]
#             }, {
#                 code: '/124506296/La_Tercera_com/LT_home/home_970x250-B',
#                 mediaTypes: {
#                     banner: {
#                         sizes: fullbanner
#                     }
#                 },
#                 bids: [{
#                     bidder: 'appnexus',
#                     params: {
#                         placementId: 15256542
#                     }
#                 }]
#             }, {
#                 code: '/124506296/La_Tercera_com/LT_home/home_970x250-C',
#                 mediaTypes: {
#                     banner: {
#                         sizes: fullbanner
#                     }
#                 },
#                 bids: [{
#                     bidder: 'appnexus',
#                     params: {
#                         placementId: 15256544
#                     }
#                 }]
#             }, {
#                 code: '/124506296/La_Tercera_com/LT_home/home_970x250-D',
#                 mediaTypes: {
#                     banner: {
#                         sizes: fullbanner
#                     }
#                 },
#                 bids: [{
#                     bidder: 'appnexus',
#                     params: {
#                         placementId: 15256545
#                     }
#                 }]
#             }
#
#         ];
#
#         var pbjs = pbjs || {};
#         pbjs.que = pbjs.que || [];
#     </script>
#
#     <script type='text/javascript'>
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         googletag.cmd.push(function () {
#             googletag.pubads().disableInitialLoad();
#         });
#
#         pbjs.que.push(function () {
#             pbjs.addAdUnits(adUnits);
#             pbjs.setConfig({
#                    priceGranularity: 'dense'
#             });
#             pbjs.setConfig({
#                 sizeConfig: [{
#                     'mediaQuery': '(min-width: 980px)',
#                     'sizesSupported': desktopSizes,
#                     'labels': ['desktop']
#                 }, {
#                     'mediaQuery': '(min-width: 768px) and (max-width: 979px)',
#                     'sizesSupported': tabletSizes,
#                     'labels': ['tablet']
#                 }, {
#                     'mediaQuery': '(min-width: 1px) and (max-width: 767px)',
#                     'sizesSupported': phoneSizes,
#                     'labels': ['phone']
#                 }]
#             });
#             pbjs.requestBids({
#                 bidsBackHandler: sendAdserverRequest
#             });
#         });
#
#         function sendAdserverRequest() {
#
#             if (pbjs.adserverRequestSent) return;
#             pbjs.adserverRequestSent = true;
#             googletag.cmd.push(function () {
#                 pbjs.que.push(function () {
#                     pbjs.setTargetingForGPTAsync();
#                     googletag.pubads().refresh();
#                 });
#             });
#         }
#
#         setTimeout(function () {
#             sendAdserverRequest();
#         }, PREBID_TIMEOUT);
#     </script>
#     <!-- Prebid Fin-->
#     <script>
#
#     googletag.cmd.push(function () {
#
#
#         var mappingFullbanner = googletag.sizeMapping().
#           addSize([980, 620 ], [970, 250]).
#           addSize([740, 580 ], [728, 90]).
#           addSize([1, 1 ], [300, 250]).
#           build();
#
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_Infooter', [1, 1], 'ads-footerexpan').addService(googletag.pubads());
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_itt', [1, 1], 'ads-intersticial').addService(googletag.pubads());
#
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_160x600', [160, 600], 'div-gpt-lt-home-0').addService(googletag.pubads());
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_300x250-A', [300, 250], 'div-gpt-lt-home-1').addService(googletag.pubads());
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_300x250-B', [300, 250], 'div-gpt-lt-home-2').addService(googletag.pubads());
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_300x250-C', [300, 250], 'div-gpt-lt-home-3').addService(googletag.pubads());
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_300x250-Cont', [300, 250], 'div-gpt-lt-home-4').addService(googletag.pubads());
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_300x250-D', [300, 250], 'div-gpt-lt-home-5').addService(googletag.pubads());
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_300x250-E', [300, 250], 'div-gpt-lt-home-6').addService(googletag.pubads());
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_300x250-F', [300, 250], 'div-gpt-lt-home-7').addService(googletag.pubads());
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_300x250-G', [300, 250], 'div-gpt-lt-home-8').addService(googletag.pubads());
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_300x250-H', [300, 250], 'div-gpt-lt-home-9').addService(googletag.pubads());
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_300x50', [300, 50], 'div-gpt-lt-home-10').addService(googletag.pubads());
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_970x250-A', [[970, 250], [728, 90], [300, 250]], 'div-gpt-lt-home-11').defineSizeMapping(mappingFullbanner).addService(googletag.pubads());
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_970x250-B', [[970, 250], [728, 90], [300, 250]], 'div-gpt-lt-home-12').defineSizeMapping(mappingFullbanner).addService(googletag.pubads());
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_970x250-C', [[970, 250], [728, 90], [300, 250]], 'div-gpt-lt-home-13').defineSizeMapping(mappingFullbanner).addService(googletag.pubads());
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_970x250-D', [[970, 250], [728, 90], [300, 250]], 'div-gpt-lt-home-14').addService(googletag.pubads());
#     googletag.defineSlot('/124506296/La_Tercera_com/LT_home/home_barra', [970, 50], 'div-gpt-lt-home-15').addService(googletag.pubads());
#                 googletag.pubads().setTargeting('CxSegments', getUserSegmentIdsLocal());
#                 googletag.pubads().setForceSafeFrame(false);
#                 googletag.pubads().setTargeting('TIPO', ['home']);
#                 googletag.pubads().setTargeting('CANAL', ['home']);
#
# 				googletag.pubads().enableSingleRequest();
# 				googletag.enableServices();
#
#     });
# </script>
# 			<script>
# 	var objectDfpBySize = {"1x1":["ads-footerexpan","ads-intersticial"],"160x600":["div-gpt-lt-home-0"],"300x250":["div-gpt-lt-home-1","div-gpt-lt-home-2","div-gpt-lt-home-3","div-gpt-lt-home-4","div-gpt-lt-home-5","div-gpt-lt-home-6","div-gpt-lt-home-7","div-gpt-lt-home-8","div-gpt-lt-home-9"],"300x50":["div-gpt-lt-home-10"],"970x250":["div-gpt-lt-home-11","div-gpt-lt-home-12","div-gpt-lt-home-13","div-gpt-lt-home-14"],"970x50":["div-gpt-lt-home-15"]}</script>
# <!-- END DFP -->
#
# <!-- Adobe Analytics -->
# <script>window.digitalData = {
# 								pageInstanceID: 'home',
# 								page:{
# 								pageInfo: {
# 											pageID: 'home',
# 											pageName: 'home',
# 											destinationURL: 'https://www.latercera.com',
# 											author: '',
# 											issueDate: '',
# 											effectiveDate: '',
# 											publisher: 'latercera.com',
# 											tags: []
# 										  },
# 								category:{
# 											primaryCategory: 'home',
# 											subCategory1: 'home',
# 											pageType: 'home'
# 										 },
# 								attributes:{
# 											country: 'CL',
# 											language: 'es-cl',
# 											server: 'latercera_prod'
# 										   }
# 									 }
# 						};
# </script>
# <script src="//assets.adobedtm.com/launch-ENeac2edc439f841af89a4a40695739fc4.min.js"></script>
# <!-- Medula -->
# <script type="text/javascript" src="https://native.sharethrough.com/assets/sfp.js" async></script>
# <!-- Google Analytics -->
#   <script>
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-27744179-98', 'auto');
# 	ga('create', 'UA-27744179-43', 'auto', 'legacytag');
# 	ga('send', 'pageview');
# 	ga('legacytag.send', 'pageview');
#       </script>
#     <!-- Google Tag Manager -->
# 	<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 	new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,'script','dataLayer','GTM-THJ3KJG');</script>
# <!-- End Google Tag Manager -->
#   <script type='text/javascript'>
# 			  var _sf_async_config = _sf_async_config || {};
# 			  /** CONFIGURATION START **/
# 			  _sf_async_config.uid = 14295;
# 			  _sf_async_config.domain = 'latercera.com';
# 			  _sf_async_config.flickerControl = false;
# 			  _sf_async_config.useCanonical = true;
# 			  _sf_async_config.useCanonicalDomain = true;
# 			  /** CONFIGURATION END **/
# 			</script>
# 			<script async src='//static.chartbeat.com/js/chartbeat_mab.js'></script></head>
# <body class="home blog header-index group-blog hfeed">
#   <!-- End Google Tag Manager (noscript) -->
#     <div id="fb-root"></div>
#   <script>(function(d, s, id) {
#     var js, fjs = d.getElementsByTagName(s)[0];
#     if (d.getElementById(id)) return;
#     js = d.createElement(s); js.id = id;
#     js.src = "//connect.facebook.net/es_LA/sdk.js#xfbml=1&version=v2.10";
#     fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
#   </script>
#   <!-- Facebook Pixel Code -->
#   <script>
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window, document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '337244956761913');
#     fbq('track', 'PageView');
#   </script>
#   <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=337244956761913&ev=PageView&noscript=1"/></noscript>
#
#   <!-- End Facebook Pixel Code -->
# 		<header class="lt-auto-hide-header main-header">
# 			<section class="top-head main-wrapper">
# 	<div class="menu-topwrp text-left">
# 		<!--<div class="inline-block">
# 			<a href="http://edition.pagesuite.com/html5/reader/production/default.aspx?pubname=&pubid=33084897-397a-48cc-b3c0-3ce1ec447137" target="_blank" class="paper-top">
# 				<div class="paper-in"><img src="http://edition.pagesuite-professional.co.uk/get_image.aspx?w=300&pbid=33084897-397a-48cc-b3c0-3ce1ec447137&pnum=01&nocache=3008201920" alt="La Tercera" class="img-responsive"></div>
# 			</a>
# 		</div>-->
# 		<nav class="rrss-nav rrss-nav-sm">
# 			<ul>
# 										<li><a href="http://twitter.com/latercera" class="defaultc" target="_blank"><span class="ltpicto-twitter"></span></a></li>
# 										<li><a href="https://www.facebook.com/laterceracom" class="defaultc" target="_blank"><span class="ltpicto-facebook"></span></a></li>
# 										<li><a href="https://flipboard.com/@latercera" class="defaultc" target="_blank"><span class="ltpicto-flipboard"></span></a></li>
# 										<li><a href="https://www.instagram.com/laterceracom/" class="defaultc" target="_blank"><span class="ltpicto-instagram"></span></a></li>
# 										<li><a href="https://www.youtube.com/latercera/" class="defaultc" target="_blank"><span class="ltpicto-youtube"></span></a></li>
# 							</ul>
# 		</nav>
# 		<nav class="nav-sm inline-block vbottom">
# 			<ul class="list-inline">
# 				<li><a href="https://especiales.latercera.com/suscripcion/" target="_blank">Por qué La Tercera</a></li>
# 				<!--<li><a href="http://comunidad.latercera.com/" class="highlight-btn" target="_blank">Suscripciones</a></li>-->
# 				<li><a href="http://www.clublatercera.com/" target="_blank">Club La Tercera</a></li>
# 				<!--<li><a href="">Avisos Legales</a></li>-->
# 				<!--<li><a href="">Remates</a></li>-->
# 			</ul>
# 		</nav>
# 	</div>
# 	<div class="menu-toplogo">
# 		<a id="trackLogo" href="https://www.latercera.com" class="main-logo"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 502.4 61.8"><style type="text/css">.red{fill:#AA272F;}.white{fill:#fff;}.lt-inv .red{fill:#fff;}.lt-inv .white{fill:#AA272F;}</style><title>La Tercera</title><rect y="1.3" class="red" width="62" height="59.6"/><polygon class="white" points="7.4 12.3 13.4 12.3 13.4 44.9 30.5 44.9 30.5 50.2 7.4 50.2 "/><polygon class="white" points="37.3 17.6 26.1 17.6 26.1 12.3 54.6 12.3 54.6 17.6 43.3 17.6 43.3 50.2 37.3 50.2 "/><polygon class="red" points="161.8 9.7 179.5 9.7 179.5 60.9 188.8 60.9 188.8 9.7 206.5 9.7 206.5 1.4 161.8 1.4 "/><path class="red" d="M297.9 24.1c0-13.8-9-22.8-25.4-22.8h-15.2v59.6h9.4V46.7h5.9c1.5 0 3-0.1 4.3-0.3l10.2 14.5h11.1L286 44C293.8 40.4 297.9 33.3 297.9 24.1zM272.2 38.7h-5.6v-29h5.6c11.4 0 16.1 5.4 16.1 14.5C288.2 33.2 283.6 38.7 272.2 38.7z"/><path class="red" d="M332.2 53.2c-12 0-20.8-9.2-20.8-22.1C311.4 18.5 320 9 331.9 9c7.9 0 12.9 2.8 16.9 8.2l7.2-5.1c-5.2-7.3-12.8-11.5-23.8-11.5 -17 0-30.4 13-30.4 30.6 0 17.6 13.1 30.6 30.1 30.6 11.6 0 19.4-4 25.5-12.2l-7.3-5C345.6 50.3 339.9 53.2 332.2 53.2z"/><path class="red" d="M447.5 24.1c0-13.8-9-22.8-25.4-22.8h-15.2v59.6h9.4V46.7h5.8c1.5 0 3-0.1 4.3-0.3l10.2 14.5h11.1L435.5 44C443.3 40.4 447.5 33.3 447.5 24.1zM421.7 38.7h-5.5v-29h5.5c11.4 0 16.1 5.4 16.1 14.5C437.8 33.2 433.2 38.7 421.7 38.7z"/><path class="red" d="M476.2 0.1h-0.5l-26.1 60.8h9.5l3.4-8.3H489l3.4 8.3h9.9L476.2 0.1zM465.9 44.3l9.9-23.6 9.7 23.6H465.9z"/><polygon class="red" points="362.4 60.9 401.2 60.9 401.2 52.6 371.8 52.6 371.8 42.5 397.1 42.5 397.1 34.4 371.8 34.4 371.8 9.7 401.2 9.7 401.2 1.4 362.4 1.4 "/><polygon class="red" points="221.8 42.5 247.1 42.5 247.1 34.4 221.8 34.4 221.8 9.7 251.5 9.7 251.5 1.4 212.4 1.4 212.4 60.9 251.6 60.9 251.6 52.6 221.8 52.6 "/><path class="red" d="M135.4 0.2l-22.5 52.4H89.2V1.4h-9.4v59.5h39l3.4-8.3h26.6l3.4 8.3h9.9L136 0.2H135.4zM125.7 44.3l9.9-23.5 9.7 23.5H125.7z"/></svg></a>
# 	</div>
# 	<div class="menu-topwrp text-right">
# 				<!-- Cxense Module: Widget Suscripciones Header LT  -->
# 		<div id="cx_b5695decdeda8700603693ccb13711b433eb75e9"></div>
# 		<script type="text/javascript">
# 		    var cX = window.cX = window.cX || {}; cX.callQueue = cX.callQueue || [];
# 		    cX.CCE = cX.CCE || {}; cX.CCE.callQueue = cX.CCE.callQueue || [];
# 		    cX.CCE.callQueue.push(['run',{
# 		        widgetId: 'b5695decdeda8700603693ccb13711b433eb75e9',
# 		        targetElementId: 'cx_b5695decdeda8700603693ccb13711b433eb75e9'
# 		    }]);
# 		</script>
# 		<!-- Cxense Module End -->
# 				<!-- se saca papel digital -->
# 		<!--
# 		<div class="digital-paper clearfix">
# 			<h1>revisa nuestro<br>papel digital<br><b>AQUí</b></h1>
# 			<div>
# 				<div class="paper-revolutions">
# 					<a href="https://edition.pagesuite.com/html5/reader/production/default.aspx?pubname=&pubid=33084897-397a-48cc-b3c0-3ce1ec447137" target="_blank">
# 						<div class="over-shadow"></div>
# 						<div class="news">
# 							<img src="https://edition.pagesuite-professional.co.uk/get_image.aspx?w=300&pbid=33084897-397a-48cc-b3c0-3ce1ec447137&pnum=01&nocache=3008201920" alt="Papel Digital">
# 						</div>
# 					</a>
# 				</div>
# 			</div>
# 			<style>
# 				.ea-log img {max-width: 100px;margin:0 0 0 auto;-webkit-animation: tilt 2s infinite; animation: tilt 2s infinite;}
# 				.ea-log a{color: #000;}
# 				.ea-app {
# 					position: absolute;
# 					right: 35px;
# 					top: 15px;
# 					width: 50px;
# 					height: 50px;
# 					border-radius: 10px;
# 					overflow: hidden;
# 					display: block;
# 					z-index: 6;
# 					box-shadow: 0 0 10px rgba(0,0,0,.25);
# 				}
# 				.ea-app img {width: 50px; height: auto; display: block;}
# 				@-webkit-keyframes tilt {
# 				  from,
# 				  50%,
# 				  to {opacity: 1;}
#
# 				  25%,
# 				  75% {opacity: .6;}
# 				}
#
# 				@keyframes tilt {
# 				  from,
# 				  50%,
# 				  to {opacity: 1;}
#
# 				  25%,
# 				  75% {opacity: .6;}
# 				}
# 			</style>
# 			<h1 class="ea-log"><a href="http://edition.pagesuite.com/launch.aspx?pbid=b56048aa-4157-4754-8bff-0c731058b546">Descarga la<br>nueva App<br><img src="https://s1.latercera.com/wp-content/uploads/2019/02/early-access.png" alt="Early Access" class="img-responsive"></a></h1>
# 			<div>
# 				<div class="paper-revolutions">
# 					<a href="http://edition.pagesuite.com/launch.aspx?pbid=b56048aa-4157-4754-8bff-0c731058b546" target="_blank">
# 						<div class="ea-app"><img src="https://s1.latercera.com/wp-content/uploads/2019/02/early-access-app2.png" alt="App"></div>
# 						<div class="over-shadow"></div>
# 						<div class="news">
# 							<img src="https://edition.pagesuite-professional.co.uk/get_image.aspx?w=300&pbid=33084897-397a-48cc-b3c0-3ce1ec447137&pnum=01&nocache=3008201920" alt="Papel Digital">
# 						</div>
# 					</a>
# 				</div>
# 			</div>
# 		</div>
# 		-->
# 		<nav class="nav-sm hidden">
# 			<ul class="list-inline">
# 				<li><a href=""><span class="ltpicto-user"></span> Acceder</a></li>
# 				<li><a href="">Regístrate</a></li>
# 			</ul>
# 		</nav>
# 	</div>
# </section>
# <hr class="divisor">
# <section class="bottom-head main-wrapper">
# 	<div class="menu-bottomlogo">
# 		<a href="https://www.latercera.com" class="behind-logo"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 502.4 61.8"><style type="text/css">.red{fill:#AA272F;}.white{fill:#fff;}.lt-inv .red{fill:#fff;}.lt-inv .white{fill:#AA272F;}</style><title>La Tercera</title><rect y="1.3" class="red" width="62" height="59.6"/><polygon class="white" points="7.4 12.3 13.4 12.3 13.4 44.9 30.5 44.9 30.5 50.2 7.4 50.2 "/><polygon class="white" points="37.3 17.6 26.1 17.6 26.1 12.3 54.6 12.3 54.6 17.6 43.3 17.6 43.3 50.2 37.3 50.2 "/><polygon class="red" points="161.8 9.7 179.5 9.7 179.5 60.9 188.8 60.9 188.8 9.7 206.5 9.7 206.5 1.4 161.8 1.4 "/><path class="red" d="
# 												<li class=""><a href="https://www.latercera.com/canal/el-deportivo/">El Deportivo</a></li>
# 												<li class=""><a href="http://culto.latercera.com">Culto</a></li>
# 												<li class=""><a href="https://www.paula.cl">Paula</a></li>
# 												<li class=""><a href="https://www.latercera.com/practico/">Práctico</a></li>
# 												<li class=""><a href="https://www.latercera.com/canal/que-pasa/">Qué Pasa</a></li>
# 												<li class=""><a href="https://www.latercera.com/canal/politica/">Política</a></li>
# 												<li class=""><a href="https://www.latercera.com/canal/nacional/">Nacional</a></li>
# 												<li class=""><a href="https://www.latercera.com/canal/tendencias/">Tendencias</a></li>
# 												<li class=""><a href="https://www.latercera.com/canal/mundo/">Mundo</a></li>
# 												<li class=""><a href="https://www.latercera.com/canal/opinion/">Opinión</a></li>
# 												<li class=""><a href="#0"><span style="display:none;">no</span><style> main.cover-page>p.small.padding-5.sans-serif.m-bottom-0.text-center.border-bottom-1.visible-xs-block, main.single-page>p.small.padding-5.sans-serif.m-bottom-0.text-center.border-bottom-1.visible-xs-block, header.main-header .menu-topwrp.text-right > p.small.inline-block.sans-serif.m-bottom-0 {display: none !important;} </style></a></li>
# 									</ul>
# 			</nav>
# 		</div>
# 		<div class="tags-excerpt">
# 			<span id="temas-headding"><em>Temas/</em></span>
# 			<nav class="nav-cat">
# 				<ul class="list-inline text-uppercase">
# 											<li><a href="https://www.latercera.com/etiqueta/brasil/">Brasil</a></li>
# 											<li><a href="https://www.latercera.com/etiqueta/alexis-sanchez/">Alexis Sánchez</a></li>
# 											<li><a href="https://www.latercera.com/etiqueta/gobierno/">Gobierno</a></li>
# 											<li><a href="https://www.latercera.com/etiqueta/economiadinero/">Economía & Dinero</a></li>
# 											<li><a href="https://www.latercera.com/etiqueta/futbol-internacional/">Fútbol Internacional</a></li>
# 									</ul>
# 			</nav>
# 		</div>
# 	</div>
#
# 	<div id="user-button" class="menu-bottomwrp menu-btn-right btn-user">
#
# 	</div>
#
# 	<div class="menu-bottomwrp menu-btn-right btn-search">
# 		<a href="#showSearch" role="button" data-toggle="collapse" aria-expanded="false" aria-controls="showSearch" class="collapsed">
# 			<span class="ltpicto-search"></span>
# 		</a>
# 	</div>
# 	<div class="menu-bottomwrp menu-btn-right">
# 		<a id="trackBurger" href="#lt-navigation" class="nav-trigger">
# 			<span><em aria-hidden="true"></em></span>
# 		</a>
# 	</div>
# </section>
# <hr class="divisor">
# <nav class="lt-primary-nav">
# 	<div id="lt-navigation">
# 			<div class="main-wrapper">
# 				<div class="row">
# 					<div class="col-md-2">
# 						<div class="visible-xs-block">
# 							<h2>#Tags</h2>
# 							<ul class="menu_vertical tags_menu m-bottom-15">
# 								<li><a href="https://www.latercera.com/etiqueta/brasil/">Brasil</a></li><li><a href="https://www.latercera.com/etiqueta/alexis-sanchez/">Alexis Sánchez</a></li><li><a href="https://www.latercera.com/etiqueta/gobierno/">Gobierno</a></li><li><a href="https://www.latercera.com/etiqueta/economiadinero/">Economía & Dinero</a></li><li><a href="https://www.latercera.com/etiqueta/futbol-internacional/">Fútbol Internacional</a></li>							</ul>
# 											<li><a href="https://www.duna.cl/"><div class="img-wrpr"><img src="https://s1.latercera.com/wp-content/uploads/2019/06/duna.png" alt="Duna"></div><span>Duna</span></a></li>
# 											<li><a href="https://www.radiozero.cl/"><div class="img-wrpr"><img src="https://s2.latercera.com/wp-content/uploads/2019/06/zero.png" alt="Duna"></div><span>Zero</span></a></li>
# 											<li><a href="https://www.beethovenfm.cl/"><div class="img-wrpr"><img src="https://s2.latercera.com/wp-content/uploads/2019/06/beethoven.png" alt="Duna"></div><span>Beethoven</span></a></li>
# 											<li><a href="http://radiodisney.disneylatino.com/chile"><div class="img-wrpr"><img src="https://s1.latercera.com/wp-content/uploads/2019/06/disney.png" alt="Duna"></div><span>Radio Disney</span></a></li>
# 							</ul>
# 		</li>
# 			</ul>
# </nav>
# 					</div>
# 				</div>
# 			</div>
# 	</div>
# </nav>
# <!--[if lt IE 10]>
# <div class="alert alert-header alert-danger alert-dismissible alert-browser" role="alert">
# 	<a class="close" href="#" data-dismiss="alert"><span class="ltpicto-close"></span></a>
# 	<p><span class="ltpicto-info"></span> EstÃ¡s usando un navegador <strong>sin soporte</strong>. Por favor <a href="http://browsehappy.com/"><strong>actualiza tu navegador <span class="ltpicto-linkout"></span></strong></a> para mejorar tu experiencia.</p>
# </div>
# 	<![endif]-->
#
# <div id="showSearch" class="collapse">
# 		<script>
# 			(function() {
# 				var cx = '001097818992342953348:wonhcwj-dss';
# 				var gcse = document.createElement('script');
# 				gcse.type = 'text/javascript';
# 				gcse.async = true;
# 				gcse.src = 'https://cse.google.com/cse.js?cx=' + cx;
# 				var s = document.getElementsByTagName('script')[0];
# 				s.parentNode.insertBefore(gcse, s);
# 			})();
# 		</script>
# 		<div class="search-box">
# 			<div class="main-wrapper">
# 							<div class="input-group input-group-lg">
# 									<!--Contenedor Custom de Google Search-->
# 									<gcse:searchbox-only></gcse:searchbox-only>
# 									<!--FIN Contenedor Custom de Google Search-->
# 									<div class="input-group-addon addon-close">
# 										<a href="#showSearch" role="button" data-toggle="collapse" aria-expanded="false" aria-controls="showSearch">
# 						<span class="ltpicto-close"></span>
# 					</a>
# 									</div>
# 							</div>
# 				 </div>
# 		</div>
# </div>
#
# </header>
#
# <main id="muestraSkinBranding" class="cover-page fill-up" role="main">
# <p class="small padding-5 sans-serif m-bottom-0 text-center border-bottom-1 visible-xs-block">Prueba un mes gratis &#124;<a href="https://suscripciondigital.latercera.com/" class="text-uppercase" target="_blank"> Suscribete</a></p>
#
#
#   <script>
#     if (document.getElementsByClassName("alert-header").length > 0) {
#       var itm = document.getElementById("topBreakingAlert");
#       var cln = itm.cloneNode(true);
#       var aels = cln.getElementsByTagName("a");
#
#       for (var i = 0; i < aels.length; i++) {
#         cln.getElementsByTagName("a")[i].removeAttribute("id");
#       }
#
#       cln.className += " invisible";
#       document.querySelector("main").insertBefore(cln, document.getElementsByTagName("main").firstChild);
#     }
#
#     if (document.getElementById("liveShow")) {
#       var itmm = document.getElementById("liveShow");
#       var clnn = itmm.cloneNode(true);
#       var aelss = clnn.getElementsByTagName("a");
#
#       for (var i = 0; i < aelss.length; i++) {
#         clnn.getElementsByTagName("a")[i].removeAttribute("id");
#       }
#
#       var myNode = clnn.getElementsByClassName("embed-responsive-16by9");
#       while (myNode[0].firstChild) {
# ...
#             </a>
#           </div>
# 					<div>
#             <a href="https://edition.pagesuite.com/html5/reader/production/default.aspx?pubname=&pubid=48f9332c-80d6-478f-af3d-5517bb6f0346" target="_blank" class="drop-shadow">
#               <div class="position-full read-over"><span class="ltpicto-read"></span></div>
#               <img src="https://edition.pagesuite-professional.co.uk/get_image.aspx?w=240&pbid=48f9332c-80d6-478f-af3d-5517bb6f0346&pnum=01&nocache=3008201920" alt="Suplemento Reportajes">
#             </a>
#           </div>
#           <div>
#             <a href="http://edition.pagesuite.com/html5/reader/production/default.aspx?pubname=&pubid=2b07d086-f618-4876-947c-d6fb49fe540b" target="_blank" class="drop-shadow">
#               <div class="position-full read-over"><span class="ltpicto-read"></span></div>
#               <img src="https://edition.pagesuite-professional.co.uk/get_image.aspx?w=240&pbid=2b07d086-f618-4876-947c-d6fb49fe540b&pnum=01&nocache=3008201920" alt="Revista Paula">
#             </a>
#           </div>
#           <div>
#             <a href="https://edition.pagesuite.com/html5/reader/production/default.aspx?pubname=&pubid=6728743c-8350-46c9-9d1a-9cb2ec6aa1dd" target="_blank" class="drop-shadow">
#               <div class="position-full read-over"><span class="ltpicto-read"></span></div>
#               <img src="https://edition.pagesuite-professional.co.uk/get_image.aspx?w=240&pbid=6728743c-8350-46c9-9d1a-9cb2ec6aa1dd&pnum=01&nocache=3008201920" alt="Revista Más Deco">
#             </a>
#           </div>
#
#           <div>
#             <a href="https://edition.pagesuite.com/html5/reader/production/default.aspx?pubname=&pubid=1ccad72c-86f1-4ed8-b7ce-d1c7fc20e55a" target="_blank" class="drop-shadow">
#               <div class="position-full read-over"><span class="ltpicto-read"></span></div>
#               <img src="https://edition.pagesuite-professional.co.uk/get_image.aspx?w=240&pbid=1ccad72c-86f1-4ed8-b7ce-d1c7fc20e55a&pnum=01&nocache=3008201920" alt="Mtmag">
#             </a>
#           </div>
#           <div>
#             <a href="https://edition.pagesuite.com/html5/reader/production/default.aspx?pubname=&pubid=09f7eff6-8116-4291-b836-8edce8105841" target="_blank" class="drop-shadow">
#               <div class="position-full read-over"><span class="ltpicto-read"></span></div>
#               <img src="https://edition.pagesuite-professional.co.uk/get_image.aspx?w=240&pbid=09f7eff6-8116-4291-b836-8edce8105841&pnum=01&nocache=3008201920" alt="La Tercera Kids">
#             </a>
#           </div>
#           <div>
#             <a href="https://edition.pagesuite.com/html5/reader/production/default.aspx?pubname=&pubid=eef26669-47ab-41ea-b0e2-6cfb84b44d9e" target="_blank" class="drop-shadow">
#               <div class="position-full read-over"><span class="ltpicto-read"></span></div>
#               <img src="https://edition.pagesuite-professional.co.uk/get_image.aspx?w=240&pbid=eef26669-47ab-41ea-b0e2-6cfb84b44d9e&nocache=3008201920" alt="Especiales 1">
#             </a>
#           </div>
#           <div>
#             <a href="https://edition.pagesuite.com/html5/reader/production/default.aspx?pubname=&pubid=489948bc-3f78-45f6-8b6e-2e9627bcae0d" target="_blank" class="drop-shadow">
#               <div class="position-full read-over"><span class="ltpicto-read"></span></div>
#               <img src="https://edition.pagesuite-professional.co.uk/get_image.aspx?w=240&pbid=489948bc-3f78-45f6-8b6e-2e9627bcae0d&nocache=3008201920" alt="Especiales 2">
#             </a>
#           </div>
#           <div>
#             <a href="https://edition.pagesuite.com/html5/reader/production/default.aspx?pubname=&pubid=11f21979-737e-4733-a7cd-91bcbe58b503" target="_blank" class="drop-shadow">
#               <div class="position-full read-over"><span class="ltpicto-read"></span></div>
#               <img src="https://edition.pagesuite-professional.co.uk/get_image.aspx?w=240&pbid=11f21979-737e-4733-a7cd-91bcbe58b503&nocache=3008201920" alt="Especiales 3">
#             </a>
#           </div>
#           <div>
#             <a href="https://edition.pagesuite.com/html5/reader/production/default.aspx?pubname=&pubid=7b0460dc-c269-4a34-829d-d8f3c70879b3" target="_blank" class="drop-shadow">
#               <div class="position-full read-over"><span class="ltpicto-read"></span></div>
#               <img src="https://edition.pagesuite-professional.co.uk/get_image.aspx?w=240&pbid=7b0460dc-c269-4a34-829d-d8f3c70879b3&nocache=3008201920" alt="Especiales 4">
#             </a>
#           </div>
#           <div>
#             <a href="https://edition.pagesuite.com/html5/reader/production/default.aspx?pubname=&pubid=f06cf70d-3e03-40ed-acf8-e87f88b35081" target="_blank" class="drop-shadow">
#               <div class="position-full read-over"><span class="ltpicto-read"></span></div>
#               <img src="https://edition.pagesuite-professional.co.uk/get_image.aspx?w=240&pbid=f06cf70d-3e03-40ed-acf8-e87f88b35081&pnum=01&nocache=3008201920" alt="Club La Tercera">
#             </a>
#           </div>
#           <div>
#             <a href="https://edition.pagesuite.com/html5/reader/production/default.aspx?pubname=&pubid=c64fe86d-9c7f-46bc-b75e-0628236785ca" target="_blank" class="drop-shadow">
#               <div class="position-full read-over"><span class="ltpicto-read"></span></div>
#               <img src="https://edition.pagesuite-professional.co.uk/get_image.aspx?w=240&pbid=c64fe86d-9c7f-46bc-b75e-0628236785ca&pnum=01&nocache=3008201920" alt="Anuario de Culto">
#             </a>
#           </div>
#         </div>
# 			</div>
# 		</div>
# 	</div>
# 	<div id="phantomNav" class="owl-nav phantom-nav nav-blue-dark"></div>
# </section>
# <footer class="main-footer">
# 	<div class="container">
# 		<div class="row p-bottom-20 p-top-20">
# 			<div class="col-md-4 logo_footer_menu">
# 				<a href="https://www.latercera.com" class="lfoot-lt lt-inv"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 502.4 61.8"><style type="text/css">.red{fill:#AA272F;}.white{fill:#fff;}.lt-inv .red{fill:#fff;}.lt-inv .white{fill:#AA272F;}</style><title>La Tercera</title><rect y="1.3" class="red" width="62" height="59.6"/><polygon class="white" points="7.4 12.3 13.4 12.3 13.4 44.9 30.5 44.9 30.5 50.2 7.4 50.2 "/><polygon class="white" points="37.3 17.6 26.1 17.6 26.1 12.3 54.6 12.3 54.6 17.6 43.3 17.6 43.3 50.2 37.3 50.2 "/><polygon class="red" points="161.8 9.7 179.5 9.7 179.
# 												<li><a href="http://canaldenuncias.grupocopesa.cl/canal-denuncias/">Canal de denuncias</a></li>
# 												<li><a href="http://remates.latercera.com/">Remates</a></li>
# 												<li><a href="https://remates-propiedades-tgr.latercera.com/">Remates TGR</a></li>
# 												<li><a href="http://avisoslegales.latercera.com/">Avisos Legales</a></li>
# 									</ul>
# 			</div>
# 		</div>
# 		<div class="row"><div class="col-xs-12"><div class="b-top-white-opacity"></div></div></div>
# 		<div class="row p-top-30 p-bottom-30">
# 			<div class="col-md-4 col-sm-4 flex-foot">
# 				<a href="http://www.grupocopesa.cl/" target="_blank" class="lfoot-gc inline-block"><img src="//s1.latercera.com/wp-content/themes/gnuble/img/logo-grupo-copesa.png" alt="Grupo Copesa"></a>
# 				<a href="https://www.iab.cl/estudio-viewability-trafico-invalido/" target="_blank" class="inline-block iab-valid"><img src="//s1.latercera.com/wp-content/themes/gnuble/img/iab-medio-auditado.png" alt="Auditado IAB"></a>
# 			</div>
# 			<div class="col-md-8 col-sm-8 hidden-xs">
# 				<div class="row margin-0">
# 					<div class="foot-logos">
# 				      <ul class="list-inline">
# 																		<li><a href="http://latercera.com/"><span class="ltc"></span></a></li>
# 																		<li><a href="http://www.pulso.cl"><span class="pls"></span></a></li>
# 																		<li><a href="http://lacuarta.com"><span class="lct"></span></a></li>
# 																		<li><a href="http://www.lahora.cl/"><span class="lhr"></span></a></li>
# 																		<li><a href="http://www.diarioconcepcion.cl/"><span class="dcn"></span></a></li>
# 																		<li><a href="http://www.paula.cl"><span class="pau"></span></a></li>
# 																		<li><a href="http://culto.latercera.com/"><span class="clt"></span></a></li>
# 																		<li><a href="http://mouse.latercera.com/"><span class="mse"></span></a></li>
# 																		<li><a href="http://www.glamorama.cl/"><span class="gla"></span></a></li>
# 																		<li><a href="http://www.biut.cl/"><span class="biu"></span></a></li>
# 																		<li><a href="http://www.icarito.cl/"><span class="ica"></span></a></li>
# 																		<li><a href="https://www.unlimitedcomics.cl/"><span class="unl"></span></a></li>
# 																		<li><a href="http://www.duna.cl/"><span class="dun"></span></a></li>
# 																		<li><a href="http://www.beethovenfm.cl/"><span class="bet"></span></a></li>
# 																		<li><a href="http://www.radiozero.cl/"><span class="zer"></span></a></li>
# 																		<li><a href="http://www.disneylatino.com/radio"><span class="dis"></span></a></li>
# 												      </ul>
# 				    </div>
# 				</div>
# 			</div>
# 		</div>
# 		<div class="row"><div class="col-xs-12"><div class="b-top-white-opacity"></div></div></div>
# 		<div class="row">
# 			<div class="col-md-12">
# 				<h5 id="copyright-footer" class="tx-white margin-top-0">© 2019 La Tercera, innovación digital. Todos los derechos reservados.</h5>
# 			</div>
# 		</div>
# 	</div>
# </footer>
# <div id="gignosko"></div>
#
#   <script type='text/javascript'>
#     function getCookie(cname) {
#       var name = cname + '=';
#       var decodedCookie = decodeURIComponent(document.cookie);
#       var ca = decodedCookie.split(';');
#       for(var i = 0; i <ca.length; i++) {
#         var c = ca[i];
#         while (c.charAt(0) == ' ') {
#           c = c.substring(1);
#         }
#         if (c.indexOf(name) == 0) {
#           return c.substring(name.length, c.length);
#         }
#       }
#       return '';
#     }
#   </script>
# 			<script type='text/javascript'>
# 				(function() {
#                   /** CONFIGURATION START **/
# 				  var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});
# 			_sf_async_config.sections = 'Portada';
#       var _cbq = window._cbq = (window._cbq || []);
#       var usrStatus = 'anon';
#
#       if (getCookie('ltprm') == 'true') {
#         usrStatus = 'paid';
#       } else if (window.localStorage.getItem('ltsess') == 'true') {
#         usrStatus = 'lgdin';
#       }
#
#       _cbq.push(['_acct', usrStatus]);
#
#
# 				/** CONFIGURATION END **/
# 			    function loadChartbeat() {
# 			          var e = document.createElement('script');
# 			          var n = document.getElementsByTagName('script')[0];
# 			          e.type = 'text/javascript';
# 			          e.async = true;
# 			          e.src = '//static.chartbeat.com/js/chartbeat.js';
# 			          n.parentNode.insertBefore(e, n);
# 			    }
# 			    loadChartbeat();
# 			  })();
# 		</script>
# 		<!-- Cxense Module: no article -->
# <script type='text/javascript'>
#
#   (function() {
#
# 	var cX = window.cX = window.cX || {}; cX.callQueue = cX.callQueue || [];
#     cX.CCE = cX.CCE || {}; cX.CCE.callQueue = cX.CCE.callQueue || [];
#
#     var lsvb = getCookie('ltprm');
#
# 	  var lttrc = getCookie('lttrc');
#
#     if (lttrc) {
#     var customParam = ((lsvb == 'true') ? 'y' : 'n');
#
# 	  cX.callQueue.push(['addExternalId', {'id': lttrc, 'type':'cps'}]);
#     cX.callQueue.push(['setCustomParameters', { 'isSubscriber': customParam }]);
#     }
#
# })();
#
# </script>
# <!-- Cxense Module End --><script type='text/javascript' src='https://s1.latercera.com/wp-content/themes/gnuble/js/ads.js?ver=1.5'></script>
# <script type='text/javascript' src='https://s2.latercera.com/wp-content/themes/gnuble/js/bootstrap.min.js?ver=v3'></script>
# <script type='text/javascript' src='https://s1.latercera.com/wp-content/themes/gnuble/js/owlcarousel/owl.carousel.min.js?ver=v3'></script>
# <script type='text/javascript' src='https://s2.latercera.com/wp-content/themes/gnuble/js/velocity.min.js?ver=v3'></script>
# <script type='text/javascript' src='https://s1.latercera.com/wp-content/themes/gnuble/js/jquery.mCustomScrollbar.js?ver=v1.1'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var homeurl = "https:\/\/www.latercera.com";
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s1.latercera.com/wp-content/themes/gnuble/js/main.js?ver=v3.4.3.3'></script>
# <script type='text/javascript' src='https://s2.latercera.com/wp-content/themes/gnuble/js/gaTrackers.js?ver=v1.2'></script>
# <script type='text/javascript' src='https://s1.latercera.com/wp-content/gnuble-bundle/dist/bundle.1566481252080.js?ver=1.0.0.0.0'></script>
# <script type='text/javascript' src='https://s1.latercera.com/wp-content/themes/gnuble/js/header.js?ver=v3.2'></script>
# <script type='text/javascript' src='https://s1.latercera.com/wp-content/themes/gnuble/js/render.js?ver=v1'></script>
# <script type='text/javascript' src='https://s2.latercera.com/wp-content/themes/gnuble/js/listerners-dfp.js?ver=v1.0.0.1'></script>
# <script type='text/javascript' src='https://s1.latercera.com/wp-includes/js/wp-embed.min.js?ver=4.8'></script>
# <script type="text/javascript">
#   window.setTimeout(function() {
#     var weareblocked = false;
#     if (typeof(adBlockEnabled) == 'undefined' ) {
#       weareblocked = true;
#     } else if (adBlockEnabled == true || typeof(loadedAdsScripts) == 'undefined') {
#     	weareblocked = true;
#     }
#
#     if (weareblocked) {
#       //enviar evento ga 'adblocked'
#       ga('send', 'event', 'blocked', 'blocked', window.location.href);
#     }
#
#   }, 1000);
# </script>
# <script type="text/javascript">_satellite.pageBottom();</script>
#
# </body>
# </html>

# %% [markdown]
# Tutorial para uso más avanzado de _Requests_:
# - _Requests_ quickstart [[1]](https://2.python-requests.org//es/latest/user/quickstart.html)
# - uso avanzado de _Requests_ [[2]](https://2.python-requests.org//es/latest/user/advanced.html)

# %% [markdown]
# ## 2. Extraer datos de documentos HTML en Python: _BeautifulSoup4_

# %% [markdown]
# [BeautifulSoup4](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) es una librería Python que facilita la extracción de datos en archivos HTML y XML.

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
from bs4 import BeautifulSoup

bs = BeautifulSoup(html_doc, 'html5lib')

# %%
a_tags = bs.find_all('a')

for a_tag in a_tags:
    print(a_tag)
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
for a_tag in a_tags:
    print(a_tag.text)
# Out:
# Elsie
# Lacie
# Tillie

# %%
for a_tag in a_tags:
    print(a_tag['href'])
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
p_tags = bs.find_all('p',attrs = {'class':'title'})
for p_tag in p_tags:
    print(p_tag.text)
# Out:
# The Dormouse's story

# %% [markdown]
# ## 3. Extraer enlaces de noticias desde un medio de prensa: _Requests_ y _BeautifulSoup4_
#
# **Nota Bene**: Multiplicar de forma automática las consultas HTTP hacia un sitio web es una mala práctica que no respeta las condiciones de uso del sitio. En ciertos paises, está prohibido por leyes.
# Para evitar abusar las condiciones de uso de los sitios, cuidaremos no enviar más de 2 consultas por minuto hacia el mismo sitio.
#
# Para evitar abusos, cada grupo de estudiantes utilizaran sitios de medios de prensa distintos:
# - La Tercera: https://www.latercera.com/
# - Cooperativa: https://www.cooperativa.cl/
# - Bio Bio: https://www.biobiochile.cl/
# - CNN Chile: https://www.cnnchile.com/
# - 24 Horas TVN: https://www.24horas.cl/
# - El País (España): https://elpais.com/elpais/portada_america.html
# - El Mundo (españa): https://www.elmundo.es/
# -

# %%
URL = "https://www.elmundo.es/ultimas-noticias.html"

r = requests.get(URL)

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=iso-8859-15"/>
# <meta http-equiv="X-UA-Compatible" content="IE=edge;chrome=1"/>
# <title data-ue-u="title" data-ue-c="innerHTML">Últimas noticias - Noticias de última hora | EL MUNDO</title>
# <link href="https://e00-elmundo.uecdn.es/favicon.ico" type="image/ico" rel="icon"/>
# <link href="https://e00-elmundo.uecdn.es/favicon.ico" type="image/ico" rel="shortcut icon"/>
# <link rel="apple-touch-icon-precomposed" href="https://e00-elmundo.uecdn.es/apple-touch-icon-precomposed.png">
# <link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://e00-elmundo.uecdn.es/apple-touch-icon-72x72-precomposed.png">
# <link rel="apple-touch-icon-precomposed" sizes="76x76" href="https://e00-elmundo.uecdn.es/apple-touch-icon-76x76-precomposed.png">
# <link rel="apple-touch-icon-precomposed" sizes="114x114" href="https://e00-elmundo.uecdn.es/apple-touch-icon-114x114-precomposed.png">
# <link rel="apple-touch-icon-precomposed" sizes="120x120" href="https://e00-elmundo.uecdn.es/apple-touch-icon-120x120-precomposed.png">
# <link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://e00-elmundo.uecdn.es/apple-touch-icon-144x144-precomposed.png">
# <link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://e00-elmundo.uecdn.es/apple-touch-icon-152x152-precomposed.png">
# <meta name="description" content="Consulta las últimas noticias de actualidad en EL MUNDO. Información de última hora actualizada al minuto sobre España, Internacional, Deportes... ¡Entra!"/>
# <meta name="keywords" content=""/>
# <meta name="news_keywords" content=""/>
# <meta name="date" content="2018-04-10T11:46:04+02:00"/>
# <meta name="robots" content="index,follow"/>
# <meta name="organization" content="Unidad Editorial Información General S.L.U."/>
# <meta name="theme-color" content="#2e6d9d">
# <!-- ##IBEXCLU --><link rel="canonical" href="https://www.elmundo.es/ultimas-noticias.html"/>
# <link rel="publisher" href="https://plus.google.com/u/0/+elmundo"/>
# <!-- ##FBEXCLU --><meta property="article:modified_time" content="2018-04-10T11:46:04+02:00"/>
# <meta property="article:section" content="Lo-mas"/>
# <meta name="twitter:card" content="summary"/>
# <meta name="twitter:site" content="@elmundoes"/>
# <meta name="twitter:title" content="Últimas noticias - Noticias de última hora | EL MUNDO"/>
# <meta name="twitter:image" content="https://e00-elmundo.uecdn.es/assets/desktop/master/img/iconos/elmundo.png"/>
# <meta name="twitter:description" content="Consulta las últimas noticias de actualidad en EL MUNDO. Información de última hora actualizada al minuto sobre España, Internacional, Deportes... ¡Entra!"/>
# <meta property="og:title" content="Últimas noticias - Noticias de última hora | EL MUNDO"/>
# <meta property="og:description" content="Consulta las últimas noticias de actualidad en EL MUNDO. Información de última hora actualizada al minuto sobre España, Internacional, Deportes... ¡Entra!"/>
# <meta property="og:url" content="https://www.elmundo.es/ultimas-noticias.html"/>
# <meta property="og:type" content="website"/>
# <meta property="og:image" content="https://e00-elmundo.uecdn.es/assets/desktop/master/img/redes-sociales/logoelmundo_rrss.png"/>
# <meta property="og:site_name" content="ELMUNDO"/>
# <meta property="fb:app_id" content="279395918757488"/>
# <link href="https://e00-elmundo.uecdn.es/rss/lo-mas.xml" title="RSS de Últimas noticias - Noticias de última hora" rel="alternate" type="application/rss+xml"/><link rel="stylesheet" type="text/css" href="https://e00-elmundo.uecdn.es/assets/v11/css/core-portada-elmundo-desktop.css"><!--[if lte IE 9]>
# <link href="https://e00-elmundo.uecdn.es/assets/v11/css/core-elmundo-desktop-ie.css" media="all" rel="stylesheet" type="text/css"/>
# <![endif]--><link rel="stylesheet" href="https://e00-elmundo.uecdn.es/assets/desktop/master/css/lomasleido/style.css" type="text/css" media="all"/>
# <script src="https://e00-elmundo.uecdn.es/assets/v11/js/jquery.2.1.4.js" type="text/javascript"></script>
# <!--[if lte IE 9]>
# <script type="text/javascript" src="https://e00-elmundo.uecdn.es/assets/desktop/master/js/jquery.ie8.js"></script>
# <![endif]--><!--[if lt IE 9]>
# <script type="text/javascript" src="https://e00-elmundo.uecdn.es/assets/desktop/master/js/html5.js"></script>
# <![endif]--><script type="text/javascript">var utilsEvent=new Event('cargaUtils');var event_youtube_player=new Event('YouTubeIframeAPIReady');</script>
# <script type="text/javascript" language="javascript" src="https://e00-ue.uecdn.es/cookies/js/policy_v3.js"></script>
# <script type="text/javascript" src="https://sdk.privacy-center.org/loader.js" data-key="03f1af55-a479-4c1f-891a-7481345171ce" id="spcloader" async></script>
# <script>var gptadslots=[],googletag=googletag||{};googletag.cmd=googletag.cmd||[]</script>
# <script src="https://e00-elmundo.uecdn.es/js/an_mu.js"></script>
# <script src="//e00-elmundo.uecdn.es/js/1475575201_elmundo.js"></script>
# <script type='text/javascript'>function loadFreemium(){if("undefined"!=typeof frm&&null!=frm&&"function"==typeof frm)frm();else{var e=document.createElement("script");e.async=!0,e.type="text/javascript";var t="https:"==document.location.protocol;e.src=(t?"https:":"http:")+"//e00-elmundo.uecdn.es/js/1475575201_elmundo.js";var r=document.getElementsByTagName("script")[0];r.parentNode.insertBefore(e,r),frm()};clearTimeout(secFrm)}var secFrm=setTimeout(function(){loadFreemium()},5e3);</script>
# <script type='text/javascript'>function initAdServer(){loadFreemium()}</script>
# <script type='text/javascript' async>var pbjs=pbjs||{};pbjs.que=pbjs.que||[];(function(){var e=document.createElement("script");e.type="text/javascript",e.async=!0,e.src="//e00-elmundo.uecdn.es/js/pbmu.js";var t=document.getElementsByTagName("head")[0];t.insertBefore(e,t.firstChild)})()</script>
# <script type="text/javascript" src="https://e00-elmundo.uecdn.es/js/uecomscore_cmp.js"></script>
# <script type="text/javascript">!function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js")</script>
# <script src="//assets.adobedtm.com/73515ad8d49a3d35d5aa6bc81b535d3a8761d99c/satelliteLib-e48bb3b61613dd24961235e0a80c02ab5b0cf8b8.js"></script>
# <script src="https://www.elmundo.es/apw.js?v=2"></script>
# <script src="https://www.elmundo.es/apw.js?f=mod&v=2"></script></head>
# <body class="lo-mas lo-mas-parent "><div id="pixelcontabilizacionelmundo" class="pixelcontabilizacion" style="position:absolute;top:0px;left:0px;width:1px;height:1px;z-Index:1"><img src="https://pixelcounter.elmundo.es/pixelcontabilizacion/pixelcontabilizacion.gifctl?r=http%3A%2F%2Fwww%2Eelmundo%2Ees%2Fultimas%2Dnoticias%2Ehtml&amp;s=elmundo&amp;d=XWmP8AoAAi4AAAAsGtY" width="1" height="1" alt="" /><script type="text/javascript">function DM_prepClient(csid,client){var cat=document.location.href.split('/');url_section=cat[6];client.DM_addEncToLoc("as_section",url_section);}</script></div>
# <script type="text/javascript">
# var cdn_cookies=function(){var e=location.hostname,o="; "+document.cookie,t={"www.elmundo.es":{cookieName:["ELMUNDO_idusr","ELMUNDO_pref","UE_pref"]},"videos.elmundo.es":{cookieName:["ELMUNDO_idusr","ELMUNDO_pref","UE_pref"],destinationHost:"www.elmundo.es"}};if(t[e])for(i=0;i<t[e].cookieName.length;i++)if(o.split("; "+t[e].cookieName[i]+"=").length<2){var n=document.createElement("img"),s=location.hostname;t[e].destinationHost&&(s=t[e].destinationHost),n.alt=" ",n.style="display:none;position:absolute;top:0px;left:0px;width:1px;height:1px;z-Index:1",n.src="//"+s+"/ue-cdn/services/cdn_cookie_service.html";var c=document.body.firstChild;c.parentNode.insertBefore(n,c);break}};cdn_cookies();
# </script>
#
# <script>var nav_continua_active=true;</script>
# <script type="text/javascript">
#     !function(t){var e;"undefined"!=typeof window?e=window:"undefined"!=typeof self&&(e=self),e.lazyload=t()}(function(){return function t(e,n,r){function o(u,c){if(!n[u]){if(!e[u]){var f="function"==typeof require&&require;if(!c&&f)return f(u,!0);if(i)return i(u,!0);var a=new Error("Cannot find module '"+u+"'");throw a.code="MODULE_NOT_FOUND",a}var l=n[u]={exports:{}};e[u][0].call(l.exports,function(t){var n=e[u][1][t];return o(n?n:t)},l,l.exports,t,e,n,r)}return n[u].exports}for(var i="function"==typeof require&&require,u=0;u<r.length;u++)o(r[u]);return o}({1:[function(t,e,n){(function(n){function r(t){-1===c.call(a,t)&&a.push(t)}function o(t){function e(t){var e=n(t);e&&(t.src=e),t.setAttribute("data-lzled",!0),i[c.call(i,t)]=null}function n(e){return"function"==typeof t.src?t.src(e):e.getAttribute(t.src)}function o(n){d&&n.classList.add(t.deprecated),n.onload=null,n.removeAttribute("onload"),n.onerror=null,n.removeAttribute("onerror"),-1===c.call(i,n)&&f(n,t,e)}t=u({offset:1048,src:"data-src",container:!1,deprecated:"force-size"},t||{}),"string"==typeof t.src&&r(t.src);var i=[];return o}function i(t){var e="HTML"+t+"Element";if(e in n!=!1){var r=n[e].prototype.getAttribute;n[e].prototype.getAttribute=function(t){if("src"===t){for(var e,n=0,o=a.length;o>n&&!(e=r.call(this,a[n]));n++);return e||r.call(this,t)}return r.call(this,t)}}}function u(t,e){for(var n in t)void 0===e[n]&&(e[n]=t[n]);return e}function c(t){for(var e=this.length;e--&&this[e]!==t;);return e}e.exports=o;var f=t("in-viewport"),a=["data-src"],l=function(){var t=navigator.userAgent,e=/like android/i.test(t),n=function(e){var n=t.match(e);return n&&n.length>1&&n[1]||""},r={};return r.device=/tablet/i.test(t)||/[^-]mobi/i.test(t),r.chrome=/CrOS|chrome|crios|crmo/i.test(t),r.android=!e&&/android/i.test(t),r.osVersion=r.android&&n(/android[ \/-](\d+(\.\d+)*)/i),r.version=n(/version\/(\d+(\.\d+)?)/i),r.device&&!r.chrome&&r.android&&parseFloat(r.osVersion)<4.4&&parseInt(r.version)<=4},d=l();n.lzld=o(),i("Image"),i("IFrame")}).call(this,"undefined"!=typeof global?global:"undefined"!=typeof self?self:"undefined"!=typeof window?window:{})},{"in-viewport":2}],2:[function(t,e,n){(function(t){function n(e,n,r){var o={container:t.document.body,offset:0};(void 0===n||"function"==typeof n)&&(r=n,n={});for(var u=o.container=n.container||o.container,c=o.offset=n.offset||o.offset,a=0;a<f.length;a++)if(f[a].container===u)return f[a].isInViewport(e,c,r);return f[f.push(i(u))-1].isInViewport(e,c,r)}function r(t,e,n){t.attachEvent?t.attachEvent("on"+e,n):t.addEventListener(e,n,!1)}function o(t,e,n){var r;return function(){function o(){r=null,n||t.apply(i,u)}var i=this,u=arguments,c=n&&!r;clearTimeout(r),r=setTimeout(o,e),c&&t.apply(i,u)}}function i(e){function n(t,e,n){if(!n)return d(t,e);var r=i(t,e,n);return r.watch(),r}function i(t,e,n){function r(){s.add(t,e,n)}function o(){s.remove(t)}return{watch:r,dispose:o}}function f(t,e,n){d(t,e)&&(s.remove(t),n(t))}function d(n,r){if(!l(t.document.documentElement,n)||!l(t.document.documentElement,e))return!1;if(!n.offsetWidth||!n.offsetHeight)return!1;var o=n.getBoundingClientRect(),i={};if(e===t.document.body)i={top:-r,left:-r,right:t.document.documentElement.clientWidth+r,bottom:t.document.documentElement.clientHeight+r};else{var u=e.getBoundingClientRect();i={top:u.top-r,left:u.left-r,right:u.right+r,bottom:u.bottom+r}}var c=o.right>=i.left&&o.left<=i.right&&o.bottom>=i.top&&o.top<=i.bottom;return c}var s=u(),p=e===t.document.body?t:e,v=o(s.checkAll(f),15);return r(p,"scroll",v),p===t&&r(t,"resize",v),a&&c(s,e,v),setInterval(v,150),{container:e,isInViewport:n}}function u(){function t(t,e,n){r(t)||i.push([t,e,n])}function e(t){var e=n(t);-1!==e&&i.splice(e,1)}function n(t){for(var e=i.length-1;e>=0;e--)if(i[e][0]===t)return e;return-1}function r(t){return-1!==n(t)}function o(t){return function(){for(var e=i.length-1;e>=0;e--)t.apply(this,i[e])}}var i=[];return{add:t,remove:e,isWatched:r,checkAll:o}}function c(t,e,n){function r(t){t.s ...
#
# </script>
# <script>lazyload({offset:1048,'deprecated':'force-size'});</script>
# <script type="text/javascript">var cookieList=document.cookie.split(';');cookieList.forEach(function(item){if(typeof item=="string"&&item.indexOf("REGMUNDO")!=-1){var ifr_seed=document.createElement("iframe");ifr_seed.src="https://5214106.fls.doubleclick.net/activityi;src=5214106;type=corp;cat=regis00;dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;ord="+Math.random()*1000000000000+"?";ifr_seed.width="1";ifr_seed.height="1";ifr_seed.style.display="none";ifr_seed.setAttribute("frameborder","0");var node=document.body.getElementsByTagName("script")[0];node.parentNode.insertBefore(ifr_seed,node);}});</script>
# <noscript>
# <iframe src="https://5214106.fls.doubleclick.net/activityi;src=5214106;type=corp;cat=regis00;dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;ord=1?" width="1" height="1" frameborder="0" style="display:none"></iframe>
# </noscript>
# <script type="text/javascript">
#
#     var IsAPSEnabled = true;
#
#
# window.Adomik = window.Adomik || {};
# Adomik.randomAdGroup = function() {
#     var rand = Math.random();
#     switch (false) {
#         case !(rand < 0.09): return "ad_ex" + (Math.floor(100 * rand));
#         case !(rand < 0.10): return "ad_bc";
#         default: return "ad_opt";
#     }
# };
#
# window.ueUserContentGoogle = (function() {
#     if (!window || !window.ueCookiesPolicy || typeof window.ueCookiesPolicy.isAccepted != 'function') {
#         console.warn('Module ueCookiesPolicy not exists.')
#         return false
#     }
#     var googleAccepted =  ueCookiesPolicy.isAccepted({vendors: 'google'})
#     if(googleAccepted === null) { googleAccepted = undefined }
#     return googleAccepted
# }());
# var data = {"networkId":"99071977","divId":"div-gpt-ad-lo-mas_e","customTargeting":{},"adSlots":[{"adUnit":"mun/lo-mas/e","customTargeting":{"p":["f"]}},{"adUnit":"mun/lo-mas/e","sizes":[[728,90],[728,250],[970,90],[970,250],[980,90],[980,180],[980,200],[980,250],[990,90],[990,200],[990,250],[1,1]],"customTargeting":{"p":["m"]}},{"adUnit":"mun/lo-mas/e","sizes":[[300,250],[300,300],[300,600],[1,1]],"customTargeting":{"p":["r"]}},{"adUnit":"mun/lo-mas/e","sizes":[[120,600],[160,600],[120,1000],[160,1000],[1,1]],"customTargeting":{"p":["si"]}},{"adUnit":"mun/lo-mas/e","sizes":[[120,600],[160,600],[120,1001],[160,1001],[1,1]],"customTargeting":{"p":["sd"]}},{"adUnit":"mun/lo-mas/e","customTargeting":{"p":["f2"]}},{"adUnit":"mun/lo-mas/e","customTargeting":{"p":["f3"]}}]};
# var sizeConfig=[{mediaQuery:"(min-width: 1024px)",sizesSupported:[[728,90],[970,90],[970,250],[980,90],[980,250],[990,250]],labels:["mega-desktop"]},{mediaQuery:"(min-width: 0px) and (max-width: 1023px)",sizesSupported:[[320,50],[320,53],[320,100]],labels:["mega-phone"]},{mediaQuery:"(min-width: 1024px)",sizesSupported:[[300,250],[300,300],[300,600]],labels:["roba3-desktop"]},{mediaQuery:"(min-width: 1024px)",sizesSupported:[[300,250],[300,300]],labels:["roba4-desktop"]},{mediaQuery:"(min-width: 0px) and (max-width: 1023px)",sizesSupported:[[300,250],[300,300],[300,600]],labels:["roba3-phone"]}];
# var adUnits=[{labelAny:["mega-desktop"],code:"div-gpt-ad-LDB1",mediaTypes:{banner:{sizes:[[728,90],[970,90],[970,250],[980,90],[980,250],[990,250]]}},bids:[{bidder:"appnexus",params:{placementId:11595029}},{bidder:"rubicon",params:{zoneId:663006,siteId:142572,accountId:15366}},{bidder:"criteo",params:{zoneId:788288}},{bidder:"smartadserver",params:{pageId:648545,formatId:54639,siteId:99915,domain:"https://prg.smartadserver.com"}},{bidder:"richaudience",params:{pid:"1nOByoBxxB",supplyType:"site"}}]},{labelAny:["mega-desktop"],code:"div-gpt-ad-LDB2",mediaTypes:{banner:{sizes:[[728,90],[970,90],[970,250],[980,90],[980,250],[990,250]]}},bids:[{bidder:"appnexus",params:{placementId:11595030}},{bidder:"rubicon",params:{zoneId:663008,siteId:142572,accountId:15366}},{bidder:"criteo",params:{zoneId:788289}},{bidder:"smartadserver",params:{pageId:648545,formatId:54640,siteId:99915,domain:"https://prg.smartadserver.com"}}]},{labelAny:["mega-desktop"],code:"div-gpt-ad-LDB3",mediaTypes:{banner:{sizes:[[728,90],[970,90],[970,250],[980,90],[980,250],[990,250]]}},bids:[{bidder:"appnexus",params:{placementId:11595031}},{bidder:"rubicon",params:{zoneId:663010,siteId:142572,accountId:15366}},{bidder:"criteo",params:{zoneId:788290}},{bidder:"smartadserver",params:{pageId:648545,formatId:54641,siteId:99915,domain:"https://prg.smartadserver.com"}},{bidder:"richaudience",params:{pid:"2FCPaUVyWe",supplyType:"site"}}]},{labelAny:["roba3-desktop"],code:"div-gpt-ad-MPU1",mediaTypes:{banner:{sizes:[[300,250],[300,300],[300,600]]}},bids:[{bidder:"appnexus",params:{placementId:11595034}},{bidder:"rubicon",params:{zoneId:663016,siteId:142572,accountId:15366}},{bidder:"criteo",params:{zoneId:788293}},{bidder:"smartadserver",params:{pageId:648545,formatId:40859,siteId:99915,domain:"https://prg.smartadserver.com"}},{bidder:"richaudience",params:{pid:"1cypJugBaX",supplyType:"site"}}]},{labelAny:["roba3-desktop"],code:"div-gpt-ad-MPU2",mediaTypes:{banner:{sizes:[[300,250],[300,300]]}},bids:[{bidder:"appnexus",params:{placementId:11595035}},{bidder:"rubicon",params:{zoneId:663018,siteId:142572,accountId:15366}},{bidder:"criteo",params:{zoneId:792327}},{bidder:"smartadserver",params:{pageId:648545,formatId:40974,siteId:99915,domain:"https://prg.smartadserver.com"}},{bidder:"richaudience",params:{pid:"0YrQs39oI7",supplyType:"site"}}]},{labelAny:["roba4-desktop"],code:"div-gpt-ad-MPU3",mediaTypes:{banner:{sizes:[[300,250],[300,300]]}},bids:[{bidder:"appnexus",params:{placementId:11595036}},{bidder:"rubicon",params:{zoneId:663020,siteId:142572,accountId:15366}},{bidder:"criteo",params:{zoneId:792329}},{bidder:"smartadserver",params:{pageId:648545,formatId:40975,siteId:99915,domain:"https://prg.smartadserver.com"}},{bidder:"richaudience",params:{pid:"e1psu0p887",supplyType:"site"}}]},{labelAny:["roba3-desktop"],code:"div-gpt-ad-MPU4",mediaTypes:{banner:{sizes:[[300,250],[300,300],[300,600]]}},bids:[{bidder:"appnexus",params:{placementId:11595037}},{bidder:"rubicon",params:{zoneId:663022,siteId:142572,accountId:15366}},{bidder:"criteo",params:{zoneId:792331}},{bidder:"smartadserver",params:{pageId:648545,formatId:40976,siteId:99915,domain:"https://prg.smartadserver.com"}},{bidder:"richaudience",params:{pid:"1tw1QFnExo",supplyType:"site"}}]},{labelAny:["mega-phone"],code:"div-gpt-ad-LDB1",mediaTypes:{banner:{sizes:[[320,50],[320,53],[320,100]]}},bids:[{bidder:"appnexus",params:{placementId:11595020}},{bidder:"rubicon",params:{zoneId:663100,siteId:142586,accountId:15366}},{bidder:"criteo",params:{zoneId:788321}},{bidder:"smartadserver",params:{pageId:648548,formatId:54723,siteId:99916,domain:"https://prg.smartadserver.com"}},{bidder:"richaudience",params:{pid:"1TZAReNxG1",supplyType:"site"}}]},{labelAny:["mega-phone"],code:"div-gpt-ad-LDB2",mediaTypes:{banner:{sizes:[[320,50],[320,53],[320,100]]}},bids:[{bidder:"appnexus",params:{placementId:11595021}},{bidder:"rubicon",params:{zoneId:663102,siteId:142586,accountId:15366}},{bidder:"criteo",params:{zoneId:788322}},{bidder ...
# var adUnits_nc = JSON.parse(JSON.stringify(adUnits));
#
# var map = {
# 	'div-gpt-ad-LDB1': 'm',
# 	'div-gpt-ad-LDB2': 'c990x50_320x53',
# 	'div-gpt-ad-LDB3': 'mb',
# 	'div-gpt-ad-MPU1': 'r',
# 	'div-gpt-ad-MPU2': 'rb',
# 	'div-gpt-ad-MPU3': 'rc',
# 	'div-gpt-ad-MPU4': 'rd',
# 	'div-gpt-ad-MPU5': 're',
# 	'div-gpt-ad-MPU6': 'rf',
# 	'div-gpt-ad-MPU7': 'rg',
# 	'div-gpt-ad-MPU8': 'rh',
# };
#
# adUnits.forEach(function(item) {
# 	if (item.code in map) {
# 		item.code = data.divId + '_' + map[item.code] + '_5acb815ae2704e57558b469e';
# 	}
# });
#
# if (typeof pbjs !== 'undefined') {
# 		pbjs.que.push(function() {
# 		pbjs.enableAnalytics([{
# 			 provider: "appnexus",
# 			 options: {
# 				 memberId: 7669
# 			 }
# 		}]);
#
#         pbjs.setConfig({
#             priceGranularity: "dense",
#             enableSendAllBids: true,
#             consentManagement: {
#                 cmpApi: 'iab',
#                 timeout: 8000,
#                 allowAuctionWithoutConsent: true
#             },
#             sizeConfig: sizeConfig
#         });
#
# 		pbjs.addAdUnits(adUnits);
#
# 		pbjs.requestBids({
# 			timeout: 1000,
# 			bidsBackHandler: function () {
# 				initAdServer();
# 			}
# 		});
# 	});
# }
#
#     googletag.cmd.push(function () {
#         data.customTargeting.t = ['lo-mas'];
# data.customTargeting.tag = [''];
# data.customTargeting.newsid = ['5acb815ae2704e57558b469e'];
#
# (function() {
# try{
# var ueseg=localStorage.getItem("dmpue_id");
# ueseg!==null? data.customTargeting.ueid=ueseg:data.customTargeting.ueid='NoUESeg';
# var ksegs=localStorage.getItem("dmpue_segs");
# ksegs!==null? data.customTargeting.ksegs=ksegs.split(','):data.customTargeting.ksegs='NoDefinido';
# }catch(err) {}
# })();
#
# window["ueDFPData"] = data;
#
# var divId = '';
# data.adSlots.forEach(function(adSlot) {
#     var adUnit = adSlot.adUnit ? adSlot.adUnit : data.adUnit;
#     var slot;
#     divId = data.divId + '_' + adSlot.customTargeting.p.join('_');
#     divId += '_' + '5acb815ae2704e57558b469e'
#     adSlot.divId = divId;
#     adUnit = '/' + data.networkId + '/' + adUnit;
#     if (adSlot.sizes) {
#         slot = googletag.defineSlot(adUnit, adSlot.sizes, adSlot.divId);
#     } else {
#         slot = googletag.defineOutOfPageSlot(adUnit, adSlot.divId);
#     }
#
#     for (var key in adSlot.customTargeting) {
#         if (adSlot.customTargeting.hasOwnProperty(key)) {
#             slot.setTargeting(key, adSlot.customTargeting[key]);
#         }
#     }
#
#     if (typeof Adomik !== 'undefined') {
# 		slot.setTargeting('ad_group', Adomik.randomAdGroup());
#     }
#
#     slot.addService(googletag.pubads());
# });
#
# if ((typeof DisableenableSingleRequest === 'undefined') || !DisableenableSingleRequest) {
#     googletag.pubads().enableSingleRequest();
# }
#
# for (var key in data.customTargeting) {
#     if (data.customTargeting.hasOwnProperty(key)) {
#         googletag.pubads().setTargeting(key, data.customTargeting[key]);
#     }
# }
#
# googletag.pubads().addEventListener('slotRenderEnded', function(event) {
#     var count = 0;
#     var interval = setInterval(function() {
#         count++;
#         if (event && event.slot) {
#             var slotElement = event.slot.getSlotElementId();
#             var container = document.querySelector('#' + slotElement);
#             jQuery(window).trigger('slotRendered', {
#                 "slotId": slotElement,
#                 "intervalId": interval
#             });
#             if (container && !event.isEmpty && event.size && event.size.length > 1 && event.size[0] > 1 && event.size[1] > 1) {
#                 container.setAttribute('style', 'height:' + container.clientHeight + 'px;');
#                 container.parentNode.parentNode.classList.add('ready');
#             }
#         }
#         if (count > 9) {
#             clearInterval(interval);
#         }
#     }, 500);
# });
#
# googletag.pubads().enableAsyncRendering();
# if (((typeof gptIsDisableInitialLoad !== 'undefined') && gptIsDisableInitialLoad) || (typeof IsAPSEnabled !== 'undefined' && IsAPSEnabled)) {
#     googletag.pubads().disableInitialLoad();
# }
#
# if (window.ueUserContentGoogle !== undefined) {
#     if (window.ueUserContentGoogle === true) {
#         googletag.pubads().setRequestNonPersonalizedAds(0);
#     } else {
#         googletag.pubads().setRequestNonPersonalizedAds(1);
#     }
# } else {
#     googletag.pubads().disableInitialLoad();
# }
# if (typeof pbjs !== 'undefined') {
#     pbjs.que.push(function() {
#         pbjs.setTargetingForGPTAsync();
#     });
# }
# googletag.enableServices();
#     });
#     function amz() {
#     var ueConsentData = localStorage.getItem('ueConsentData');
#     apstag.init({
#         pubID: '3537',
#         adServer: 'googletag',
#         bidTimeout: 1e3,
#         gdpr: {
#             enabled: Boolean(ueConsentData),
#             consent: ueConsentData
#         }
#     });
#
#     var aps_data = {slots:[]};
#     googletag.destroySlots(googletag.pubads().getSlots().filter(function(x){ return !(x.getSlotElementId() in window)}));
#     googletag.pubads().getSlots().forEach(function(adSlot, i) {
#         var sizes = adSlot.getSizes();
#         if (sizes.length > 0) {
#             sizes = sizes.map(function(adSlotSize) {
#                     return [adSlotSize.getWidth(), adSlotSize.getHeight()];
#                 })
#                 .filter(function(size) {
#                     return (size[0] !== 1) && (size[1] !== 1);
#                 });
#             if (sizes.length > 0) {
#                 aps_data.slots.push({
#                     slotID: adSlot.getSlotElementId(),
#                     slotName: adSlot.getAdUnitPath(),
#                     sizes: sizes
#                 });
#             }
#         }
#     });
#     apstag.fetchBids(aps_data, function(bids) {
#         googletag.cmd.push(function() {
#             apstag.setDisplayBids();
#             googletag.pubads().refresh();
#         });
#     });
# }
# amz = (function(amz) {
#     var DOMContentLoadedReady = false;
#     window.addEventListener('DOMContentLoaded', function() {
#         DOMContentLoadedReady = true;
#     });
#     return function() {
#         DOMContentLoadedReady ? amz() : window.addEventListener('DOMContentLoaded', amz)
#     };
# })(amz);
# if (window.ueUserContentGoogle !== undefined) {
#   googletag.cmd.push(function () {
#     if (typeof IsAPSEnabled !== 'undefined' && IsAPSEnabled) {
#         amz();
#     }
#   });
# }else{
#     window.addEventListener('ueConsentChanged', function (event) {
#         googletag.cmd.push(function () {
#             if(  event.detail.consents.vendors.google === true ){
#                 googletag.pubads().setRequestNonPersonalizedAds(0);
#             }else{
#                 googletag.pubads().setRequestNonPersonalizedAds(1);
#             }
#             if (typeof IsAPSEnabled !== 'undefined' && IsAPSEnabled) {
#                 amz();
#             }else{
#                 googletag.pubads().refresh();
#             }
#         });
#     }, false);
# }
# </script>
# <script async=true src='https://e00-elmundo.uecdn.es/assets/uelogin/v1/ueLogin.7052fe39f88b864dc3b8.js' charset='utf-8'></script>
# <header class="site-header js-cnav-header main-section-header   section-header inside" data-ue-model="">
# <div class="container-header">
# <div class="site-logo">
# <div class="logo"><a href="https://www.elmundo.es"><span class="hidden-content">El Mundo</span></a></div>
# <aside class="tools-header">
# <ul class="tools-header-corporative">
# <li class="tools-corporative-subscription">
# <a href="https://clk.tradedoubler.com/click?p=271574&a=2404199&g=23242684" title="Suscripciones El Mundo" class="tools-corporative-link">Suscr&iacute;bete</a>
# </li>
# <li class="tools-corporative-login toolbar-login nav-login js-ueUserPanel"></li>
# </ul>
# </aside>
# <div id="pixelcontabilizacionNLalerta" class="pixelcontabilizacion" style="position:absolute;top:0px;left:0px;width:1px;height:1px;z-index:1">
# <img src="https://impes.tradedoubler.com/imp?type(inv)g(23242684)a(2404199)" width="1" height="1" alt=""/>
# </div>
# </div>
# </div>
# <div class="nav-container js-desdefixed js-hastafixed">
# <div class="container-header">
# <nav role="navigation" class="js-navTab">
# <ul class="nav-tabs js-mainNavigation">
#
# <li class="tab tab-national" data-section="espana">
# <a href="https://www.elmundo.es/espana.html?intcmp=MENUHOM24801&s_kw=espana" data-menu-active="espana">España</a>
# <div class="tab-container" id="submenuNational">
# <ul class="tab-content">
# <li><span class="tab-header">Secciones</span></li>
# <li class="tab-list">
# <a href="https://www.elmundo.es/espana.html?intcmp=MENUDES22301&s_kw=espana" class="tab-list-header">Portada</a></li>
# <li class="tab-list">
# <a href="https://www.elmundo.es/madrid.html?intcmp=MENUDES22301&s_kw=madrid" class="tab-list-header">Madrid</a></li>
# <li class="tab-list">
# <a href="https://www.elmundo.es/andalucia.html?intcmp=MENUDES22301&s_kw=andalucia" class="tab-list-header">Andalucía</a>
# <ul>
# <li class="tab-list-link"><a href="https://www.elmundo.es/andalucia/sevilla.html?intcmp=MENUDES22301&s_kw=sevilla">Sevilla</a></li>
# <li class="tab-list-link"><a href="https://www.elmundo.es/andalucia/malaga.html?intcmp=MENUDES22301&s_kw=malaga">Málaga</a></li>
# <li class="tab-list-link"><a href="https://www.elmundo.es/andalucia/el-caminante.html?intcmp=MENUDES22301&s_kw=el_caminante">El Caminante</a></li>
# </ul>
# </li>
# <li class="tab-list">
# <a href="https://www.elmundo.es/baleares.html?intcmp=MENUDES22301&s_kw=baleares" class="tab-list-header">Baleares</a>
# <ul>
# <li class="tab-list-link"><a href="https://www.elmundo.es/baleares/ibiza.html?intcmp=MENUDES22301&s_kw=ibiza">Ibiza</a></li>
# <li class="tab-list"><a href="https://www.elmundo.es/television/programacion-tv/?intcmp=MENUDES22301&s_kw=program_tv" class="tab-list-header">Guía TV - Programación</a></li>
# </ul>
# </div>
# </li>
#
# <li class="tab tab-science" data-section="ciencia-y-salud">
# <a href="https://www.elmundo.es/ciencia-y-salud.html?intcmp=MENUHOM24801$s_kw=ciencia-salud" data-menu-active="ciencia-y-salud">Ciencia y Salud</a>
# </li>
#
# <li class="tab tab-technology" data-section="tecnologia">
# <a href="https://www.elmundo.es/tecnologia.html?intcmp=MENUHOM24801&s_kw=tecnologia" data-menu-active="tecnologia">Tecnología</a>
# <div class="tab-container" id="submenuTechnology">
# <ul class="tab-content">
# <li><span class="tab-header">Secciones</span></li>
# <li class="tab-list">
# <a href="https://www.elmundo.es/tecnologia.html?intcmp=MENUDES22301&s_kw=tecnologia" class="tab-list-header">Portada</a>
# </li>
# <li class="tab-list"><a href="https://www.elmundo.es/tecnologia/gadgets.html?intcmp=MENUDES22301&s_kw=gadgets" class="tab-list-header">Gadgets</a></li>
# <li class="tab-list"><a href="https://www.elmundo.es/tecnologia/trucos.html?intcmp=MENUDES22301&s_kw=trucos" class="tab-list-header">Trucos</a></li>
# <li class="tab-list"><a href="https://www.elmundo.es/tecnologia/creadores.htmlintcmp=MENUDES22301&s_kw=creadores" class="tab-list-header">Creadores</a></li>
# <li class="tab-list"><a href="https://www.elmundo.es/tecnologia/videojuegos.html?intcmp=MENUDES22301&s_kw=videojuegos" class="tab-list-header">Videojuegos</a></li>
# <li class="tab-list"><a href="https://www.elmundo.es/tecnologia/innovacion.html?intcmp=MENUDES22301&s_kw=innovacion" class="tab-list-header">Innovación</a></li>
# </ul>
# </div>
# </li>
#
# <li class="tab tab-loc" data-section="loc">
# <a href="https://www.elmundo.es/loc.html?intcmp=MENUHOM24801&s_kw=loc" data-menu-active="loc">LOC</a>
# </li>
#
# <li class="menu" data-insertar>
# <div class="nav-toggle">
# <a href="https://www.elmundo.es/menu.html" class="btn-nav-toggle js-supermenu-portada" data-menu-section-path-click="https://www.elmundo.es/em/supermenu-portada.html">
# <span class="icon-text" data-click-role="cambiarIconos">
# Más<i class="icon-arrow_down_12x12_a"></i>
# </span>
# <span class="icon-text" data-click-role="cambiarIconos">
# Cerrar<i class="icon-close_12x12_d"></i>
# </span>
# </a>
# </div>
# </li>
# </ul>
# </nav>
# <div class="header-search" aria-label="Buscador">
# <form action="https://cgi.elmundo.es/perl/busca-generico.html" method="get" class="js-search-portada" role="search">
# <input type="search" name="cadena" placeholder="Buscar en elmundo.es" title="Buscar en elmundo.es">
# <input type="hidden" name="donde" value="11" id="enelmundoes">
# <input value="" name="b_avanzada" type="hidden">
# <div class="search-btn js-searchClick-portada">
# <a href="https://cgi.elmundo.es//buscador/archivo.html" title="Buscador El Mundo">
# <span><i class="icon-search_16x16_a"></i><strong>Buscar</strong></span>
# </a>
# </div>
# <span class="close-btn js-close-btn-portada"><i class="icon-close_16x16_a"></i></span>
# </form>
# </div>
# </div>
# </div>
# <div class="breadcrumbs ">
# <div class="container-header">
# <div class="clearfix "><ul itemscope="" itemtype="http://schema.org/BreadcrumbList" class="tab-breadcrumb js-containerbreadcrumb"><li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListIt
portes/futbol/primera-division/calendario.html">Calendario Liga Santander</a></li><li data-section="mibebeyyo"><a title="Mibebeyyo" href="https://mibebeyyo.elmundo.es/">Mibebeyyo</a></li><li data-section="etapas-vuelta"><a title="Etapas Vuelta" href="https://www.elmundo.es/deportes/ciclismo/vuelta-a-espana/2019/08/21/5d5d71e7fdddff023b8b466a.html">Etapas Vuelta</a></li><li data-section="clasificacion-vuelta"><a title="Clasificacion Vuelta" href="https://www.elmundo.es/deportes/ciclismo/vuelta-a-espana/clasificacion/general.html">Clasificacion Vuelta</a></li></ul></div>
# <label for="show-more-breadcrumb" class=" dropdown-submenu dropdown-more-breadcrumb js-botonera-more">
# <span class="show-more-breadcrumb-open">Más<i class="iconsvg iconsvg-more-b"></i></span>
# <span class="show-more-breadcrumb-close no-visible">Cerrar<i class="iconsvg iconsvg-close-b"></i></span>
# </label>
# <div class="dropdown-container no-visible" data-items="">
# <ul class="dropdown-content"></ul>
# </div><div class="tab-news js-breadcrumbChildren">
# <span class="tab-news-title js-newsTitle"></span>
# <aside class="aside-tools">
# <ul class="socialMedia js_socialMedia">
# <li>
# <i class="icon-facebook icon-facebook_36_d js-icon-facebook"></i><span class="hidden-content">Compartir en Facebook</span>
# </li>
# <li>
# <i class="icon-twitter icon-twitter_36_d js-icon-twitter"></i><span class="hidden-content">Compartir en Twitter</span>
# ...
# </h2>
# </header>
# <footer class="mod-footer">
# <meta itemprop="datePublished" content="2019-08-30T16:55:09+02:00">
# <time class="mod-date" itemprop="dateModified" datetime="2019-08-30T17:08:43+02:00">
# <strong>30-08-2019</strong>
# <strong>17:08</strong>
# </time>
# </footer>
# </article>
# </li>
# <li class="content-item">
# <article class="mod-item mod-news mod-default" itemtype="http://schema.org/NewsArticle"><figure class="multimedia-item" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <a href="https://www.elmundo.es/espana/2019/08/30/5d693216fdddffe0348b4680.html" title="Agentes de la Policía vigilan a los inmigrantes que han llegado a Ceuta tras saltar la valla.">
# <img itemprop="contentUrl" src="https://e00-elmundo.uecdn.es/assets/multimedia/imagenes/2019/08/30/15671751860847.jpg" alt="Agentes de la Policía vigilan a los inmigrantes que han llegado a Ceuta tras saltar la valla." title="Agentes de la Policía vigilan a los inmigrantes que han llegado a Ceuta tras saltar la valla.">
# </a>
# </figure>
# <header class="mod-header">
# <h2 class="mod-title" itemprop="headline">
# <a href="https://www.elmundo.es/espana/2019/08/30/5d693216fdddffe0348b4680.html" title="PP, Ciudadanos y Vox apoyan a los guardias civiles heridos en Ceuta y piden más medios para proteger la frontera" itemprop="url">PP, Ciudadanos y Vox apoyan a los guardias civiles heridos en Ceuta y piden más medios para proteger la frontera</a>
# </h2>
# </header>
# <footer class="mod-footer">
# <meta itemprop="datePublished" content="2019-08-30T16:26:30+02:00">
# <time class="mod-date" itemprop="dateModified" datetime="2019-08-30T17:01:14+02:00">
# <strong>30-08-2019</strong>
# <strong>17:01</strong>
# </time>
# </footer>
# </article>
# </li>
# <li class="content-item">
# <article class="mod-item mod-news mod-default" itemtype="http://schema.org/NewsArticle"><figure class="multimedia-item" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <a href="https://www.elmundo.es/espana/2019/08/30/5d69367ffdddfff03b8b46e2.html" title="Vista del cazaminas &#039;Turia&#039;, encallado en La Manga.">
# <img itemprop="contentUrl" src="https://e00-elmundo.uecdn.es/assets/multimedia/imagenes/2019/08/30/15671762718915.jpg" alt="Vista del cazaminas &#039;Turia&#039;, encallado en La Manga." title="Vista del cazaminas &#039;Turia&#039;, encallado en La Manga.">
# </a>
# </figure>
# <header class="mod-header">
# <h2 class="mod-title" itemprop="headline">
# <a href="https://www.elmundo.es/espana/2019/08/30/5d69367ffdddfff03b8b46e2.html" title="La Armada contrata a una empresa para reflotar el cazaminas varado junto a La Manga del Mar Menor" itemprop="url">La Armada contrata a una empresa para reflotar el cazaminas varado junto a La Manga del Mar Menor</a>
# </h2>
# </header>
# <footer class="mod-footer">
# <meta itemprop="datePublished" content="2019-08-30T16:45:19+02:00">
# <time class="mod-date" itemprop="dateModified" datetime="2019-08-30T22:29:10+02:00">
# <strong>30-08-2019</strong>
# <strong>22:29</strong>
# </time>
# </footer>
# </article>
# </li>
# </ul>
# </div></ul></div></section>
# <section class="row-layout"><div class="container-include"><ul><li class="content-item"><aside class="ad-item js_fixed"><div id='div-gpt-ad-lo-mas_e_r_5acb815ae2704e57558b469e' class="publicidad"><script type='text/javascript'>googletag.cmd.push(function(){googletag.display('div-gpt-ad-lo-mas_e_r_5acb815ae2704e57558b469e');});</script></div></aside></ul></div></section>
# </div>
# </div>
# </section>
# <script>jQuery.noConflict();jQuery(function(){if(typeof jQuery.fn.Tab==='function'){jQuery('#js_5acb815ae2704e57558b469e').find('.js-tabs').Tab();}
# if(typeof jQuery.fn.ElementoFijo==='function'){jQuery('#js_5acb815ae2704e57558b469e').find('.js_fixed').ElementoFijo({elementosAnteriores:['.site-header'],elementoDesdeFixed:'.js_fixed_container ',minWidthFijo:768});}});</script>
# </main>
# <footer class="site-footer horizontal" role="contentinfo">
# <div class="container-list-footer js-toggle-footer">
# <div class="js-botonera-toggle arrow-toggle" role="button" aria-expanded="false" aria-controls="webs_ue" onclick="footerToggle()">
# <h3>Otras webs de Unidad Editorial</h3>
# </div>
# <section role="region" aria-label="Otras webs de Unidad Editorial" class="js-contenido-toggle container-toggle" id="webs_ue">
# <ul class="list-footer">
# <li class="highlight"><span>El Mundo</span></li>
# <li><a href="https://clk.tradedoubler.com/click?p=271538&amp;a=2404199&amp;g=23657328" target="_blank"><span>El Mundo en Orbyt</span></a></li>
# <li><a href="https://www.elmundo.es/economia/vivienda.html" target="_blank"><span>Su Vivienda</span></a></li>
# <li><a href="https://www.elmundo.es/television/programacion-tv/" target="_blank"><span>Guía TV</span></a></li>
# <li><a href="https://inversionesinmobiliarias.elmundo.es/" target="_blank"><span>Inversiones inmobiliarias</span></a></li>
# <li><a href="https://descuentos.elmundo.es" target="_blank"><span>Descuentos El Mundo</span></a></li>
# <li><a href="https://viajar.elmundo.es/" target="_blank"><span>Viajes El Mundo</span></a></li>
# </ul>
# <div id="pixelcontabilizacionNLalerta" class="pixelcontabilizacion" style="position:absolute;top:0px;left:0px;width:1px;height:1px;z-index:1">
# <img src="https://impes.tradedoubler.com/imp?type(inv)g(23657328)a(2404199)" width="1" height="1" alt="">
# </div>
# <ul class="list-footer">
# <li class="highlight"><span>Ocio y Salud</span></li>
# <li><a href="http://www.telva.com/" target="_blank"><span>Telva</span></a></li>
# <li><a href="http://www.buhomag.com/" target="_blank"><span>El Búho</span></a></li>
# <li><a href="http://www.recetasdecocinadesergio.com/" target="_blank"><span>Recetas de cocina de Sergio</span></a></li>
# <li><a href="https://mibebeyyo.elmundo.es/" target="_blank"><span>Mi beb&eacute; y yo</span></a></li>
# <li><a href="https://cuidateplus.marca.com/" target="_blank"><span>Cuídate Plus</span></a></li>
# <li><a href="http://www.diariomedico.com/" target="_blank"><span>Diario Médico</span></a></li>
# </ul>
# <ul class="list-footer">
# <li class="highlight"><span>Unidad Editorial</span></li>
# <li><a href="http://www.expansion.com/" target="_blank"><span>Expansión</span></a></li>
# <li><a href="https://www.marca.com" target="_blank"><span>MARCA</span></a></li>
# <li><a href="https://deportes.marcaapuestas.es/es" target="_blank"><span>Apuestas Deportivas MARCA</span></a></li>
# <li><a href="https://esports.marca.com" target="_blank"><span>MARCA eSports</span></a></li>
# <li><a href="https://saposyprincesas.elmundo.es/" target="_blank"><span>Sapos y Princesas</span></a></li>
# </ul>
# <ul class="list-footer">
# <li class="highlight"><span>Empleo</span></li>
# <li><a href="http://www.escuelaunidadeditorial.es/" target="_blank"><span>Escuela Unidad Editorial</span></a></li>
# <li><a href="http://www.unidadeditorial.es/" target="_blank"><span>Unidad Editorial</span></a></li>
# <li><a href="http://www.expansion.com/expansion-empleo.html" target="_blank"><span>Expansión y Empleo</span></a>
# </li>
# </ul>
# </section>
# </div>
# <div class="container-about-footer">
# <div class="container">
# <ul class="partners">
# <li><a href="https://www.elmundo.es/em/codigo-etico.html"><i class="icon-thetrustproject_b"></i><span class="hidden-content">The Trust project</span></a></li>
# <li><a href="http://www.reverso.net/" rel="nofollow"><i class="icon-partners-reverso"></i><span class="hidden-content">Powered by Reverso</span></a></li>
# </ul>
# <ul class="about-list">
# <li class="copyright">
# <span class="icon-elmundo-mobile"></span>
# <address aria-label="Dirección y datos de contacto">© <span>Unidad Editorial Información General, S.L.U. Avda San Luis 25 - 28033 Madrid</span></address>
# </li>
# </ul>
# <section aria-label="Redes Sociales" class="footer-social-networks">
# <ul>
# <li><a href="https://twitter.com/elmundoes" class="icon-twitter" target="_blank" title="Twitter" itemprop="sameAs"><i class="icon-twitter_30_a"></i><span class="hidden-content">Siguenos en Twitter</span></a></li>
# <li><a href="https://www.facebook.com/elmundo" class="icon-facebook" target="_blank" title="Facebook" itemprop="sameAs"><i class="icon-facebook_30_a"></i><span class="hidden-content">Siguenos en Facebook</span></a></li>
# <li><a href="https://www.elmundo.es/rss/" class="icon-rss" title="RSS" target="_blank" itemprop="sameAs"><i class="icon-rss_30_a"></i><span class="hidden-content">Agregar RSS</span></a></li>
# </ul>
# </section>
# </div>
# </div>
# <div class="container-list-footer">
# <div class="container">
# <nav role="navigation" aria-label="Menú corporativo">
# <ul class="list-corporative">
# <li><a href="http://cookies.unidadeditorial.es/" class="js-uecookiespolicy-preferences-show">Política de cookies</a></li>
# <li><a href="https://www.elmundo.es/privacidad/">Política de privacidad</a></li>
# <li><a href="https://www.uesyndication.com/">Venta de contenidos</a></li>
# <li><a href="https://www.elmundo.es/privacidad/avisolegal.html">Términos y condiciones de uso</a></li>
# <li><a href="http://www.unidadeditorial.com/publicidad">Publicidad</a></li>
# <li><a href="http://www.ojd.es/">Certificado por OJD</a></li>
# <li><a href="https://www.elmundo.es/registro/contacto.html">Contacto</a></li>
# </ul>
# </nav>
# </div>
# </div>
# </footer>
# <script>if(typeof gptIsDisableInitialLoad!=='undefined'&&gptIsDisableInitialLoad){if(typeof IsAPSEnabled==='undefined'||!IsAPSEnabled){googletag.cmd.push(function(){googletag.pubads().refresh();});}}</script>
# <script src="https://e00-elmundo.uecdn.es/assets/v11/js/legazy.min.js" type="text/javascript"></script>
# <script>if(utilsEvent){window.dispatchEvent(utilsEvent);}</script>
# <script src="https://e00-elmundo.uecdn.es/assets/v11/js/desktop.min.js" type="text/javascript"></script>
# <script type="text/javascript">function onYouTubeIframeAPIReady(){document.dispatchEvent(event_youtube_player);};jQuery("header .js-breadcrumbChildren li a[href^='https://www.elmundo.es/ultimas-noticias.html']").closest("li").addClass("active");</script><script language="javaScript" type="text/javascript">function autoRefresh()
# {window.location=location.href;}
# setTimeout('autoRefresh()',eval(900*1000));</script>
# <noscript>
# <meta http-equiv="Refresh" content="900"/>
# </noscript> <!-- SiteCatalyst code version: H.25.1.
# Copyright 1996-2012 Adobe, Inc. All Rights Reserved
# More info available at http://www.omniture.com --><script language="JavaScript" type="text/javascript" data-ue-omniture>
# var s = {};var pageName = "https://www.elmundo.es/ultimas-noticias.html";s.pageType="";
# s.pageName=pageName;s.channel="ultimas-noticias";s.prop1="";
# s.prop2="";
# s.prop3="";
# s.prop4="";
# s.prop5="";
# s.prop6="";s.prop7="elmundo.es";s.prop11="Últimas noticias - Noticias de última hora-5acb815ae2704e57558b469e";s.hier1="elmundo.es|ultimas-noticias";
# s.prop27="web";
#     s.prop28="0|0";
# s.prop29="ultimas-noticias";
# s.list2="ultimas-noticias";
# s.prop30="";
#         s.prop52="";
#     s.prop53="";
#     s.prop32="pagecontent";
# s.hier1 = "elmundo.es|ultimas-noticias" + "|" + "pagecontent";s.prop33="lo-mas";
# s.prop35="origen";
# s.prop36="";
# s.prop39="nuevo-10-02";s.prop75="";
# /* Conversion Variables */
# s.eVar1=s.channel;
# s.eVar2=s.prop1;
# s.eVar3=s.prop2;
# s.eVar4=s.prop3;
# s.eVar5=s.prop4;
# s.eVar6=s.prop5;
# s.eVar7=s.prop7;
# s.eVar11=s.prop11;
# s.eVar27=s.prop27;
# s.eVar28=s.prop28;
# s.eVar29=s.prop29;
# s.eVar30=s.prop30;
# s.eVar31=s.prop6;
# s.eVar32=s.prop32;
# s.eVar33=s.prop33;
# s.eVar39=s.prop39;
# s.eVar52=s.prop52;
# s.eVar53=s.prop53;
# s.eVar75=s.prop75;
# var s_omniture = s;<!-- ==== pageName="https://www.elmundo.es/ultimas-noticias.html" ==== -->
# <!-- ==== pageType="" ==== -->
# <!-- ==== channel="ultimas-noticias" ==== -->
# <!-- ==== prop1="" ==== -->
# <!-- ==== prop2="" ==== -->
# <!-- ==== prop3="" ==== -->
# <!-- ==== prop4="" ==== -->
# <!-- ==== prop5="" ==== -->
# <!-- ==== prop6="" ==== -->
# <!-- ==== prop7="elmundo.es" ==== -->
# <!-- ==== prop11="Últimas noticias - Noticias de última hora-5acb815ae2704e57558b469e" ==== -->
# <!-- ==== hier1="elmundo.es|ultimas-noticias" ==== -->
# <!-- ==== prop29="ultimas-noticias" ==== -->
# <!-- ==== list2="ultimas-noticias" ==== -->
# <!-- ==== prop30="" ==== -->
# <!-- ==== prop32="pagecontent" ==== -->
# <!-- ==== prop33="lo-mas" ==== -->
# <!-- ==== prop35="origen" ==== -->
# <!-- ==== prop36="" ==== -->
# <!-- ==== prop39="nuevo-10-02" ==== -->
# <!-- ==== prop75="" ==== -->
# /************* DO NOT ALTER ANYTHING BELOW THIS LINE ! **************/
# </script>
# <script type="text/javascript">function DM_prepClient(csid,client){client.DM_cat("ultimas-noticias > lo-mas > pagina");}</script>
# <div id="tradedoubler"></div>
# <script type="text/javascript">setTimeout(function(){var TDConf=TDConf||{};TDConf.Config={protocol:document.location.protocol,containerTagId:"12029"};var asinTD=document.createElement("script");if(typeof(TDConf)!="undefined"){TDConf.sudomain=("https:"==document.location.protocol)?"swrap":"wrap";TDConf.host=".tradedoubler.com/wrap";TDConf.containerTagURL=(("https:"==document.location.protocol)?"https://":"http://")+TDConf.sudomain+TDConf.host;if(typeof(TDConf.Config)!="undefined"){asinTD.type='text/javascript';asinTD.async=true;asinTD.src=TDConf.containerTagURL+"?id="+TDConf.Config.containerTagId;var container=document.getElementById("tradedoubler");container.appendChild(asinTD);}}},3500);</script>
# <script type="text/javascript">(function(window){var appName='ueFooterBanner'
# var capaSelector="banda_suscripcion"
# var banda
# function isEnabled(){var valorCookie=window.document.cookie.replace(new RegExp('(?:(?:^|.*;\\s*)'+'ELMUNDO_suscrp'+'\\s*\\=\\s*([^;]*).*$)|^.*$'),'$1');return(valorCookie=='')}
# function isVisible(){banda||(banda=window.document.getElementById(capaSelector))
# if(banda&&banda.style&&banda.style.bottom==="0px"){return true}else{return false}}
# function hide(){banda||(banda=window.document.getElementById(capaSelector))
# if(banda&&banda.style){banda.style.bottom="-70px";}}
# function show(){banda||(banda=window.document.getElementById(capaSelector))
# banda.style.bottom="0px";}
# function close(){setCookie()
# hide()}
# function setCookie(){var days=1;var myDate=new Date();myDate.setTime(myDate.getTime()+(days*24*60*60*1000));window.document.cookie="ELMUNDO_suscrp = suscrip_yes; expires = "+myDate.toGMTString();}
# function checkSuscription(){banda||(banda=window.document.getElementById(capaSelector))
# if(isEnabled()){if(!isVisible()){show();setCookie();}else{window.document.removeEventListener("scroll",checkSuscription);}}}
# var app={close:close,hide:hide}
# if(window instanceof Object){if(typeof window[appName]==='undefined'){Object.defineProperty(window,appName,{value:app,writable:false})}else{console.warn('Library '+appName+" cannot be declared because it's already exists.")}}
# window.document.addEventListener("scroll",checkSuscription);}(window));</script>
# <aside id="banda_suscripcion" class="banda_suscripcion">
# <div class="wrap">
# <a target="_blank" href="https://www.elmundo.es/promociones/cocheslegendarios/?cid=PR26401&amp;s_kw=pro_foo_cocheslegendarios" rel="nofollow">
# Coches legendarios.Este sábado con EL MUNDO la réplica del Jaguar XJ por sólo 3,95 €<span class="suscribete">¡INFÓRMATE!</span>
# </a>
# <div class="cerrar icon-cerrar_16_d" onclick="ueFooterBanner.close();" title="Cerrar"></div>
# </div>
# <div id="pixelcontabilizacionsuscripcion" class="pixelcontabilizacion" style="position:absolute;top:0px;left:0px;width:1px;height:1px;z-index:1">
# <img sRc="https://impes.tradedoubler.com/imp?type(inv)g(23967072)a(2404199)" width="1" height="1" alt=""/>
# </div>
# </aside>
# <img src="//amplifypixel.outbrain.com/pixel?mid=008d6342efb6be8a979dc0f7a159804afd"><!-- SiteCatalyst code version: H.21.
# Copyright 1996-2010 Adobe, Inc. All Rights Reserved
# More info available at http://www.omniture.com -->
# <script type="text/javascript">_satellite.pageBottom();</script>
# <script type="text/javascript"><!--
# if(navigator.appVersion.indexOf('MSIE')>=0)document.write(unescape('%3C')+'!-'+'-')
# //--></script><noscript><img src="https://smetrics.el-mundo.net/b/ss/uevistatest/1/H.21--NS/0"
# height="1" width="1" alt="" /></noscript><!--/DO NOT REMOVE/-->
# </body>
# </html>

# %%
bs = BeautifulSoup(r.text, 'html5lib')

a_tags = bs.find_all('a')

for a_tag in a_tags:
    print(a_tag['href'])
# Out:
# https://www.elmundo.es
# https://clk.tradedoubler.com/click?p=271574&a=2404199&g=23242684
# https://www.elmundo.es/espana.html?intcmp=MENUHOM24801&s_kw=espana
# https://www.elmundo.es/espana.html?intcmp=MENUDES22301&s_kw=espana
# https://www.elmundo.es/madrid.html?intcmp=MENUDES22301&s_kw=madrid
# https://www.elmundo.es/andalucia.html?intcmp=MENUDES22301&s_kw=andalucia
# https://www.elmundo.es/andalucia/sevilla.html?intcmp=MENUDES22301&s_kw=sevilla
# https://www.elmundo.es/andalucia/malaga.html?intcmp=MENUDES22301&s_kw=malaga
# https://www.elmundo.es/andalucia/el-caminante.html?intcmp=MENUDES22301&s_kw=el_caminante
# https://www.elmundo.es/baleares.html?intcmp=MENUDES22301&s_kw=baleares
# https://www.elmundo.es/baleares/ibiza.html?intcmp=MENUDES22301&s_kw=ibiza
# https://www.elmundo.es/catalunya.html?intcmp=MENUDES22301&s_kw=catalunya
# https://www.elmundo.es/comunidad-valenciana.html?intcmp=MENUDES22301&s_kw=comunidad-valenciana
# https://www.elmundo.es/comunidad-valenciana/alicante.html?intcmp=MENUDES22301&s_kw=alicante
# https://www.elmundo.es/comunidad-valenciana/castellon.html?intcmp=MENUDES22301&s_kw=castellon
# https://www.elmundo.es/andalucia/2019/08/30/5d690384fc6c832d7c8b4685.html
# https://www.elmundo.es/espana/2019/08/30/5d68ea00fc6c8338388b4611.html
# https://www.elmundo.es/cultura/toros/2019/08/30/5d6950a1fc6c83ed368b45c6.html
# https://www.elmundo.es/internacional/2019/08/30/5d6941a021efa0d4258b45f4.html
# https://www.elmundo.es/album/internacional/2019/08/30/5d6933de21efa030088b45c9.html
# https://www.elmundo.es/deportes/ciclismo/vuelta-a-espana/2019/08/30/5d694b2ffdddffe6248b45e9.html
# https://www.elmundo.es/cultura/cine/2019/08/30/5d692168fc6c83fa3a8b45da.html
# https://www.elmundo.es/album/yodona/moda/2019/08/27/5d653d75fc6c83c73c8b466e.html
# https://www.elmundo.es/internacional/2019/08/30/5d694156fc6c83d5418b461d.html
# https://www.elmundo.es/cronica/2019/08/30/5d53e59efc6c8352448b469d.html
# https://www.elmundo.es/espana/2019/08/30/5d69415a21efa0ce108b45f1.html
# https://www.elmundo.es/pais-vasco/2019/08/30/5d691d3021efa02a0e8b45ff.html
# https://www.elmundo.es/f5/escucha/2019/08/30/5d6946a9fdddff15448b45cf.html
# https://www.elmundo.es/internacional/2019/08/30/5d69423cfdddff73668b4661.html
# https://www.elmundo.es/deportes/tenis/us-open/2019/08/30/5d6901f321efa0e8128b464c.html
# https://www.elmundo.es/cultura/musica/2019/08/30/5d694027fc6c83d5418b4615.html
# https://www.elmundo.es/f5/mira/2019/08/30/5d6936c4fc6c83100b8b45e5.html
# https://www.elmundo.es/deportes/futbol/primera-division/2019/08/30/5d693198fc6c83a3798b4595.html
# https://www.elmundo.es/economia/empresas/2019/08/30/5d6938cdfdddffda5c8b4650.html
# https://www.elmundo.es/espana/2019/08/30/5d693216fdddffe0348b4680.html
# https://www.elmundo.es/espana/2019/08/30/5d69367ffdddfff03b8b46e2.html

# %% [markdown]
# ## 4. Extraer contenidos de noticias

# %%
import time

noticias=[]

for enlace in enlaces:
    
    time.sleep(2)
    print(enlace)
    r = requests.get(enlace)

    bs = BeautifulSoup(r.text, 'html5lib')

    div_noticia = bs.find('div', attrs={'class':'ue-l-article__body ue-c-article__body'})

    p_tags = div_noticia.find_all('p')

    texto_noticia=""
    try:
        for p_tag in p_tags:
            texto_noticia = texto_noticia+p_tag.text
            
    except:
        continue
    noticias.append((enlace,texto_noticia))
# Out:
# https://www.elmundo.es/espana/2019/08/30/5d696387fdddff44448b456e.html
# https://www.elmundo.es/espana/2019/08/30/5d698be5fdddff830d8b458a.html
# https://www.elmundo.es/cultura/toros/2019/08/30/5d69835dfc6c833a488b45de.html
# https://www.elmundo.es/cultura/toros/2019/08/30/5d6980d7fc6c83235b8b463b.html
# https://www.elmundo.es/salud/2019/08/30/5d69300c21efa0e32d8b4608.html
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-41a8ee98dff0> in <module>
#       7     time.sleep(2)
#       8     print(enlace)
# ----> 9     r = requests.get(enlace)
#      10
#      11     bs = BeautifulSoup(r.text, 'html5lib')
#
# ~/.local/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/.local/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/.local/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/.local/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/.local/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/.local/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.5/http/client.py in getresponse(self)
#    1195         try:
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#    1199                 self.close()
#
# /usr/lib/python3.5/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/lib/python3.5/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/lib/python3.5/socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# /usr/lib/python3.5/ssl.py in recv_into(self, buffer, nbytes, flags)
#     927                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     928                   self.__class__)
# --> 929             return self.read(nbytes, buffer)
#     930         else:
#     931             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.5/ssl.py in read(self, len, buffer)
#     789             raise ValueError("Read on closed or unwrapped SSL socket.")
#     790         try:
# --> 791             return self._sslobj.read(len, buffer)
#     792         except SSLError as x:
#     793             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.5/ssl.py in read(self, len, buffer)
#     573         """
#     574         if buffer is not None:
# --> 575             v = self._sslobj.read(len, buffer)
#     576         else:
#     577             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
noticias[2]
# Out:
# ('https://www.elmundo.es/cultura/toros/2019/08/30/5d69835dfc6c833a488b45de.html',
#  'Tras romper el paseíllo, Daniel Luque fue obligado a saludar tras su encerrona del pasado 14 de agosto, saludo que compartió con sus compañeros de cartel.El primero de la tarde fue un toro muy bien presentado. Extraordinario quite por chicuelinas de Luque que replica por saltilleras Castella. Saludó tras parear José Chacon. Inició la faena el francés con dos pases cambiados por la espalda, tropezándole el toro, cayendo al suelo y teniendo los recursos de seguir toreando con las dos rodillas en tierra. La faena tuvo la virtud del temple hasta que el astado duró, recurriendo entonces Castella a acortar las distancias. Mató de media estocada, según informa Aplausos.Variado y largo fue el recibo de capote de Castella al cuarto de la tarde con verónicas y chicuelinas. Llevó al toro al caballo por chicuelinas ceñidas que realizó una buena pelea. Quitó por gaoneras Luque y saludaron tras parear Rafael Viotti y Santiago Pérez. Faena importante y maciza de Castella en la que hubo series mandonas de muletazos profundos y templados. Fue bajando el toro antes de matar de estocada trasera.Muy bajo y bien hecho fue el segundo de Algarra. Bien verónica Luque ante un toro bravo en dos encuentros en el caballo. La faena del de Gerena fue interesantísima. El inicio fue muy torero saliéndose a los medios con despaciosidad y toreando a placer en tres series importantes con la derecha. Bajó un poco el tono con la izquierda, pero remontó matando de un estoconazo resistiéndose el toro a doblar. Cortó una oreja y el toro fue premiado con la vuelta al ruedo.El quinto fue el más deslucido del encierro. Lo mejor de la actuación de Daniel Luque fue en el recibo de capote con siete u ocho verónicas con ritmo y empaque rematados con una media entre los olés del publico. Faena brindada a Castella que inició de rodillas en tierra, pero que no tuvo opción de lucimiento ya que el toro se agarró al piso y no permitió el lucimiento.El tercero fue un toro de menos peso que sus hermanos que se frenó en el capote. Peleó bien en el caballo y llegó a la muleta embistiendo con carácter. Aguado firmó dos series por el pitón derecho antes de torear con la zurda en el grueso de la faena en series que gustaron mucho. Mató de dos pinchazos y estocada ladeada.El que cerró plaza fue un toro que se defendía y se desplazó sin clase en la muleta de Aguado. El sevillano, a fuerza de sobarle y meterse en su terreno, le arrancó los pases con gran mérito. El público no entendió el esfuerzo del sevillano. Mató de estocada. Bayona (Francia), viernes 30 de agosto de 2019. Toros de Luis Algarra, muy bien presentados, de juego variado e interesante en su conjunto. Gran nota tuvieron 1º, 2º y 4º; los más deslucidos fueron 5º y 6º. El 2º, herrado con el número 33, de nombre Tostador, de 554 kg y nacido en noviembre de 2014, fue premiado con la vuelta al ruedo. Sebastián Castella, oreja y dos orejas; Daniel Luque, oreja tras aviso y silencio; Pablo Aguado, silencio tras aviso y palmas. Entrada: Más de tres cuartos. Saludaron tras parear José Chacón, al primero; y Rafael Viotti y Santiago Pérez al cuarto.Conforme a los criterios deThe Trust Project')

# %% [markdown]
# ## 5. Aplicar procesos de Tratamiento Automático del Lenguaje

# %% [markdown]
# [SpaCy](https://spacy.io) es una librería Python que permite facilitar la realización de ciertos procesos de Tratamiento Automático del Lenguaje (TAL). Ejemplos de procesos de TAL son por ejemplos:
# - la tokenización: segmentar el texto en palabras,
# - la clasificación gramatical (pos): identificar si una palabra es un sustantivo, verbo, adjetivo, etc.
# - la lematización: determinar la forma genérica de una palabra (por ej.: "superó" --> "superar", "ocasiones" --> "ocasión")

# %%
import spacy
nlp = spacy.load('es_core_news_md')

# %%
doc=nlp(noticias[1][1])

# %%
for token in doc:
    print(token.text, token.pos_,token.lemma_)
# Out:
# Podemos AUX Podemos
# ha AUX haber
# cesado VERB cesar
# este DET este
# viernes NOUN viernes
# a ADP a
# Bruno PROPN Bruno
# Pérez PROPN Pérez
# Juncà PROPN Juncà
# , PUNCT ,
# recién ADV recién
# nombrado ADJ nombrar
# director NOUN director
# general ADJ general
# de ADP de
# Administración PROPN Administración
# Electrónica PROPN Electrónica
# y CONJ y
# Sociedad PROPN Sociedad
# del ADP del
# Conocimiento PROPN Conocimiento
# del ADP del
# Gobierno PROPN Gobierno
# de ADP de
# Aragón PROPN Aragón
# , PUNCT ,
# por ADP por
# haber AUX haber
# apoyado VERB apoyar
# al ADP al
# independentismo NOUN independentismo
# catalán ADJ catalán
# . PUNCT .
# Su DET Su
# elección NOUN elección
# para ADP parir
# el DET el
# cargo NOUN cargar
# , PUNCT ,
# según ADP según
# la DET lo
# formación NOUN formación
# morada ADJ morar
# , PUNCT ,
# había AUX haber
# respondido VERB responder
# a ADP a
# su DET su
# " PUNCT "
# excelente ADJ excelente
# currículo NOUN currículo
# profesional ADJ profesional
# como SCONJ comer
# experto NOUN experto
# informático ADJ informático
# y CONJ y
# en ADP en
# ciberseguridad NOUN ciberseguridad
# " PUNCT "
# . PUNCT .
# Sin ADP Sin
# embargo NOUN embargar
# , PUNCT ,
# Bruno PROPN Bruno
# Pérez PROPN Pérez
# no ADV no
# aportó VERB aportar
# a ADP a
# los DET lo
# responsables NOUN responsable
# del ADP del
# Departamento PROPN Departamento
# de ADP de
# Ciencia PROPN Ciencia
# , PUNCT ,
# Universidad PROPN Universidad
# y CONJ y
# Sociedad PROPN Sociedad
# del ADP del
# Conocimiento PROPN Conocimiento
# , PUNCT ,
# en ADP en
# manos NOUN mano
# de ADP de
# Podemos AUX Podemos
# , PUNCT ,
# " PUNCT "
# información NOUN información
# relevante ADJ relevante
# en ADP en
# cuanto NOUN cuanto
# a ADP a
# su DET su
# actividad NOUN actividad
# política ADJ político
# pasada ADJ pasar
# lo DET el
# cual PRON cual
# quiebra VERB quebrar
# la DET lo
# confianza NOUN confianza
# que PRON que
# se PRON se
# depositó VERB depositar
# en ADP en
# el DET el
# " PUNCT "
# . PUNCT .
# Según SCONJ Según
# publica VERB publicar
# Heraldo.es PROPN Heraldo.es
# , PUNCT ,
# Pérez PROPN Pérez
# diseñó VERB diseñar
# en ADP en
# el DET el
# pasado NOUN pasar
# con ADP con
# velas NOUN velar
# grandes ADJ grande
# esteladas NOUN estelado
# ( PUNCT (
# banderas NOUN bandera
# independentistas ADJ independentista
# ) PUNCT )
# , PUNCT ,
# en ADP en
# las DET los
# plazas NOUN plaza
# de ADP de
# municipios NOUN municipio
# catalanes ADJ catalán
# . PUNCT .
# En ADP En
# Llívia PROPN Llívia
# ( PUNCT (
# Gerona PROPN Gerona
# ) PUNCT )
# , PUNCT ,
# la DET lo
# instalación NOUN instalación
# sirvió VERB servir
# de ADP de
# antesala NOUN antesala
# a ADP a
# la DET lo
# consulta NOUN consultar
# ilegal ADJ ilegal
# del ADP del
# 1 NUM 1
# de ADP de
# octubre NOUN octubre
# de ADP de
# 2017 NUM 2017
# . PUNCT .
# Incluso ADV Incluso
# se PRON se
# pretendía VERB pretender
# lograr VERB lograr
# un DET uno
# Récord PROPN Récord
# Guinness PROPN Guinness
# , PUNCT ,
# " PUNCT "
# pero CONJ pero
# como SCONJ comer
# eran AUX ser
# motivos NOUN motivo
# políticos ADJ político
# no ADV no
# coló VERB colar
# " PUNCT "
# , PUNCT ,
# según SCONJ según
# ha AUX haber
# explicado VERB explicar
# Bruno PROPN Bruno
# Pérez PROPN Pérez
# . PUNCT .
# Es AUX Es
# precisamente ADV precisamente
# su DET su
# pasado ADJ pasar
# creativo NOUN creativo
# el DET el
# que PRON que
# ha AUX haber
# hecho VERB hacer
# que SCONJ que
# se PRON se
# cuestione VERB cuestionar
# su DET su
# idoneidad NOUN idoneidad
# para ADP parir
# ocupar VERB ocupar
# el DET el
# cargo NOUN cargar
# . PUNCT .
# Tras ADP Tras
# su DET su
# designación NOUN designación
# como SCONJ comer
# alto ADJ alto
# cargo NOUN cargar
# del ADP del
# Gobierno PROPN Gobierno
# de ADP de
# Aragón PROPN Aragón
# hace AUX hacer
# apenas ADV apenar
# 24 NUM 24
# horas NOUN hora
# , PUNCT ,
# en ADP en
# su DET su
# biografía NOUN biografiar
# se PRON se
# detalló VERB detallar
# que SCONJ que
# nació VERB nacer
# en ADP en
# Figueras PROPN Figueras
# ( PUNCT (
# Gerona PROPN Gerona
# ) PUNCT )
# , PUNCT ,
# su DET su
# condición NOUN condición
# de ADP de
# técnico NOUN técnico
# superior ADJ superior
# informático ADJ informático
# especialista ADJ especialista
# en ADP en
# ciberseguridad NOUN ciberseguridad
# , PUNCT ,
# que PRON que
# es AUX ser
# perito NOUN perito
# judicial ADJ judicial
# informático ADJ informático
# y CONJ y
# que PRON que
# ha AUX haber
# colaborado VERB colaborar
# con ADP con
# varios DET vario
# medios NOUN medio
# de ADP de
# comunicación NOUN comunicación
# . PUNCT .
# Pérez PROPN Pérez
# Juncà PROPN Juncà
# creía VERB creer
# que SCONJ que
# su DET su
# pasado NOUN pasar
# con ADP con
# las DET los
# esteladas NOUN estelado
# de ADP de
# luz NOUN luz
# no ADV no
# le PRON le
# invalidaba VERB invalidar
# para ADP parir
# ocupar VERB ocupar
# una DET uno
# dirección NOUN dirección
# general ADJ general
# : PUNCT :
# " PUNCT "
# Honestamente ADV Honestamente
# , PUNCT ,
# como SCONJ comer
# técnico NOUN técnico
# y CONJ y
# experto ADJ experto
# en ADP en
# ciberseguridad NOUN ciberseguridad
# a ADP a
# mí PRON mí
# nadie PRON nadie
# me PRON me
# pregunta VERB preguntar
# por ADP por
# mi DET mi
# trabajo NOUN trabajar
# ni CONJ ni
# qué PRON qué
# hado ADJ hado
# ni CONJ ni
# dejo AUX dejar
# de ADP de
# hace AUX hacer
# " PUNCT "
# . PUNCT .
# Por ADP Por
# eso PRON ese
# " PUNCT "
# en ADP en
# ningún DET ninguno
# momento NOUN momento
# " PUNCT "
# comentó VERB comentar
# a ADP a
# los DET lo
# miembros NOUN miembro
# de ADP de
# Podemos PROPN Podemos
# Aragón PROPN Aragón
# el DET el
# tema NOUN temer
# de ADP de
# las DET los
# velas NOUN velar
# , PUNCT ,
# " PUNCT "
# que PRON que
# ha AUX haber
# sido AUX ser
# siempre ADV siempre
# muy ADV muy
# personal ADJ personal
# " PUNCT "
# . PUNCT .
# Además ADV Además
# de ADP de
# iluminar VERB iluminar
# localidades NOUN localidad
# catalanas ADJ catalán
# con ADP con
# sus DET su
# esteladas NOUN estelado
# de ADP de
# luz NOUN luz
# ha AUX haber
# realizado VERB realizar
# montajes NOUN montaje
# en ADP en
# la DET lo
# catedral NOUN catedral
# de ADP de
# Burgos PROPN Burgos
# y CONJ y
# ha AUX haber
# recreado VERB recrear
# banderas NOUN bandera
# de ADP de
# Escocia PROPN Escocia
# y CONJ y
# Francia PROPN Francia
# . PUNCT .
# Con ADP Con
# la DET lo
# " PUNCT "
# afición NOUN afición
# de ADP de
# las DET los
# velas NOUN velar
# " PUNCT "
# empezó VERB empezar
# en ADP en
# 2012 NOUN 2012
# , PUNCT ,
# y CONJ y
# lo PRON el
# hizo AUX hacer
# replicando VERB replicar
# una DET uno
# técnica NOUN técnico
# que PRON que
# aprendió VERB aprender
# en ADP en
# Petra PROPN Petra
# ( PUNCT (
# Jordania PROPN Jordania
# ) PUNCT )
# . PUNCT .
# Ganó VERB Ganó
# un DET uno
# concurso NOUN concursar
# e CONJ e
# inició VERB iniciar
# un DET uno
# proyecto NOUN proyectar
# con ADP con
# el DET el
# que PRON que
# ayudaba VERB ayudar
# a ADP a
# chicos NOUN chico
# discapacitados ADJ discapacitado
# que PRON que
# , PUNCT ,
# según SCONJ según
# explicó VERB explicar
# , PUNCT ,
# le PRON le
# permitió VERB permitir
# diseñar VERB diseñar
# una DET uno
# estelada NOUN estelado
# con ADP con
# velas NOUN velar
# que PRON que
# como SCONJ comer
# artista NOUN artista
# le PRON le
# servía VERB servir
# " PUNCT "
# para ADP parir
# escribir VERB escribir
# un DET uno
# mensaje NOUN mensaje
# de ADP de
# luz NOUN luz
# , PUNCT ,
# de ADP de
# paz NOUN paz
# , PUNCT ,
# de ADP de
# ilusión NOUN ilusión
# y CONJ y
# de ADP de
# esperanza NOUN esperanzar
# " PUNCT "
# . PUNCT .
# Empezó VERB Empezó
# en ADP en
# 2012 NOUN 2012
# por ADP por
# la DET lo
# plaza NOUN plaza
# de ADP de
# Figueras PROPN Figueras
# , PUNCT ,
# le PRON le
# pidieron VERB pedir
# que SCONJ que
# repitiera VERB repetir
# por ADP por
# el DET el
# día NOUN día
# de ADP de
# San PROPN San
# Juan PROPN Juan
# y CONJ y
# , PUNCT ,
# más ADV más
# tarde ADV tardar
# , PUNCT ,
# " PUNCT "
# se PRON se
# vinculó VERB vincular
# a ADP a
# una DET uno
# feria NOUN feriar
# de ADP de
# productos NOUN producto
# independentistas ADJ independentista
# " PUNCT "
# . PUNCT .
# " PUNCT "
# Vi VERB Vi
# la DET lo
# oportunidad NOUN oportunidad
# de ADP de
# ir VERB ir
# pueblo NOUN poblar
# a ADP a
# pueblo NOUN poblar
# , PUNCT ,
# era AUX ser
# mi DET mi
# tiempo NOUN tiempo
# libre ADJ librar
# , PUNCT ,
# no ADV no
# cobraba VERB cobrar
# nada PRON nadar
# . PUNCT .
# Me PRON Me
# tocó VERB tocar
# pagar VERB pagar
# muchas DET mucho
# veces NOUN vez
# los DET lo
# desplazamientos NOUN desplazamiento
# " PUNCT "
# , PUNCT ,
# ha AUX haber
# explicado VERB explicar
# . PUNCT .
# Era AUX Era
# su DET su
# " PUNCT "
# motivación".También ADV motivación".También
# ha AUX haber
# manifestado VERB manifestar
# que SCONJ que
# a ADP a
# Aragón PROPN Aragón
# venía VERB venir
# a ADP a
# " PUNCT "
# hacer VERB hacer
# una DET uno
# faena NOUN faenar
# técnica ADJ técnico
# " PUNCT "
# . PUNCT .
# " PUNCT "
# Me PRON Me
# vinieron VERB venir
# con ADP con
# esta DET este
# propuesta NOUN proponer
# que PRON que
# me PRON me
# ha AUX haber
# gustado VERB gustar
# porque SCONJ porque
# creo VERB creer
# que SCONJ que
# puedo AUX poder
# aportar VERB aportar
# muchísimo ADV muchísimo
# . PUNCT .
# Pero CONJ Pero
# no ADV no
# tengo VERB tener
# ninguna DET ninguno
# necesidad NOUN necesidad
# . PUNCT .
# Si SCONJ Si
# esto PRON este
# se PRON se
# complica VERB complicar
# a ADP a
# mí PRON mí
# no ADV no
# me PRON me
# interesa VERB interesar
# " PUNCT "
# , PUNCT ,
# indicó VERB indicar
# , PUNCT ,
# antes ADV antes
# de ADP de
# ser AUX ser
# cesado VERB cesar
# . PUNCT .
# Conforme NOUN Conforme
# a ADP a
# los DET lo
# criterios NOUN criterio
# deThe PROPN deThe
# Trust PROPN Trust
# Project PROPN Project

# %%
for token in doc:
    if (token.pos_ == "NOUN"):
        print(token.text, token.pos_,token.lemma_)
# Out:
# viernes NOUN viernes
# director NOUN director
# independentismo NOUN independentismo
# elección NOUN elección
# cargo NOUN cargar
# formación NOUN formación
# currículo NOUN currículo
# experto NOUN experto
# ciberseguridad NOUN ciberseguridad
# embargo NOUN embargar
# responsables NOUN responsable
# manos NOUN mano
# información NOUN información
# cuanto NOUN cuanto
# actividad NOUN actividad
# confianza NOUN confianza
# pasado NOUN pasar
# velas NOUN velar
# esteladas NOUN estelado
# banderas NOUN bandera
# plazas NOUN plaza
# municipios NOUN municipio
# instalación NOUN instalación
# antesala NOUN antesala
# consulta NOUN consultar
# octubre NOUN octubre
# motivos NOUN motivo
# creativo NOUN creativo
# idoneidad NOUN idoneidad
# cargo NOUN cargar
# designación NOUN designación
# cargo NOUN cargar
# horas NOUN hora
# biografía NOUN biografiar
# condición NOUN condición
# técnico NOUN técnico
# ciberseguridad NOUN ciberseguridad
# perito NOUN perito
# medios NOUN medio
# comunicación NOUN comunicación
# pasado NOUN pasar
# esteladas NOUN estelado
# luz NOUN luz
# dirección NOUN dirección
# técnico NOUN técnico
# ciberseguridad NOUN ciberseguridad
# trabajo NOUN trabajar
# momento NOUN momento
# miembros NOUN miembro
# tema NOUN temer
# velas NOUN velar
# localidades NOUN localidad
# esteladas NOUN estelado
# luz NOUN luz
# montajes NOUN montaje
# catedral NOUN catedral
# banderas NOUN bandera
# afición NOUN afición
# velas NOUN velar
# 2012 NOUN 2012
# técnica NOUN técnico
# concurso NOUN concursar
# proyecto NOUN proyectar
# chicos NOUN chico
# estelada NOUN estelado
# velas NOUN velar
# artista NOUN artista
# mensaje NOUN mensaje
# luz NOUN luz
# paz NOUN paz
# ilusión NOUN ilusión
# esperanza NOUN esperanzar
# 2012 NOUN 2012
# plaza NOUN plaza
# día NOUN día
# feria NOUN feriar
# productos NOUN producto
# oportunidad NOUN oportunidad
# pueblo NOUN poblar
# pueblo NOUN poblar
# tiempo NOUN tiempo
# veces NOUN vez
# desplazamientos NOUN desplazamiento
# faena NOUN faenar
# propuesta NOUN proponer
# necesidad NOUN necesidad
# Conforme NOUN Conforme
# criterios NOUN criterio

# %% [markdown]
# ## 6. Almacenar los resultados en una base de datos: _MySQL_

# %%
import mysql.connector

db_connection = mysql.connector.connect(user="root",host="localhost",password="root")
cursor = db_connection.cursor()

# %%
##EJECUTAR 1 VEZ
#cursor.execute("CREATE DATABASE info229;")
cursor.execute("USE info229")
#cursor.execute("CREATE TABLE news (idNews INT PRIMARY KEY NOT NULL AUTO_INCREMENT, url VARCHAR(200), text TEXT);")

# %%
for noticia in noticias:
    query="INSERT INTO news(url,text) VALUES (%s,%s)"
    cursor.execute(query,noticia)

cursor.execute("COMMIT");
